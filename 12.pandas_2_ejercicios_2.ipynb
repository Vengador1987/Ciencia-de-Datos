# %% [markdown]
# ## Ejercicio pandas 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Ejercicio 0:
# - Carga ambos archivos **"titanic_1.csv"** y **"titanic_2.csv"** y guardalos en **`df1`** y **`df2`** respectivamente:

# %%
df1 = pd.read_csv("titanic_1.csv")
df2 = pd.read_csv("titanic_2.csv")

# %% [markdown]
# ### Ejercicio 1:
# - Mostrar las estadisticas de cada uno de los DataFrames.

# %%
df1.describe()
# Out:
#        PassengerId         Age
# count   891.000000  714.000000
# mean    446.000000   29.699118
# std     257.353842   14.526497
# min       1.000000    0.420000
# 25%     223.500000   20.125000
# 50%     446.000000   28.000000
# 75%     668.500000   38.000000
# max     891.000000   80.000000

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass        Fare
# count   891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   32.204208
# std     257.353842    0.486592    0.836071   49.693429
# min       1.000000    0.000000    1.000000    0.000000
# 25%     223.500000    0.000000    2.000000    7.910400
# 50%     446.000000    0.000000    3.000000   14.454200
# 75%     668.500000    1.000000    3.000000   31.000000
# max     891.000000    1.000000    3.000000  512.329200

# %% [markdown]
# ### Ejercicio 2:
# - Unir los DataFrames para obtener solo uno.

# %%
df = pd.merge(left = df1, right = df2, on = "PassengerId")

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  Survived  Pclass            Ticket     Fare
# 0    22.0         0       3         A/5 21171   7.2500
# 1    38.0         1       1          PC 17599  71.2833
# 2    26.0         1       3  STON/O2. 3101282   7.9250
# 3    35.0         1       1            113803  53.1000
# 4    35.0         0       3            373450   8.0500
# ..    ...       ...     ...               ...      ...
# 886  27.0         0       2            211536  13.0000
# 887  19.0         1       1            112053  30.0000
# 888   NaN         0       3        W./C. 6607  23.4500
# 889  26.0         1       1            111369  30.0000
# 890  32.0         0       3            370376   7.7500
#
# [891 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 3:
# - Imprimir las últimas 5 filas de las columnas de nombre y edad

# %%
df[["Name", "Age"]].tail(5)
# Out:
#                                          Name   Age
# 886                     Montvila, Rev. Juozas  27.0
# 887              Graham, Miss. Margaret Edith  19.0
# 888  Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                     Behr, Mr. Karl Howell  26.0
# 890                       Dooley, Mr. Patrick  32.0

# %% [markdown]
# ### Ejercicio 4:
# - Imprimir las primeras 10 filas de las instancias que en sexo sean igual a femenino.

# %%
df[df["Sex"] == "female"].head(10)
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2             3                             Heikkinen, Miss. Laina  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   female
# 18           19  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
#
#      Age  Survived  Pclass            Ticket     Fare
# 1   38.0         1       1          PC 17599  71.2833
# 2   26.0         1       3  STON/O2. 3101282   7.9250
# 3   35.0         1       1            113803  53.1000
# 8   27.0         1       3            347742  11.1333
# 9   14.0         1       2            237736  30.0708
# 10   4.0         1       3           PP 9549  16.7000
# 11  58.0         1       1            113783  26.5500
# 14  14.0         0       3            350406   7.8542
# 15  55.0         1       2            248706  16.0000
# 18  31.0         0       3            345763  18.0000

# %% [markdown]
# ### Ejercicio 5:
# - Imprimir las instancias que en la columna **`Fare`** sean menor a 33 y en la columna **`Pclass`** igual a 2.

# %%
ej5 = df[(df["Fare"] < 33) & (df["Pclass"] == 2)]

# %%
ej5
# Out:
#      PassengerId                                          Name     Sex   Age  \
# 9             10           Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 15            16              Hewlett, Mrs. (Mary D Kingcome)   female  55.0
# 17            18                  Williams, Mr. Charles Eugene    male   NaN
# 20            21                          Fynney, Mr. Joseph J    male  35.0
# 21            22                         Beesley, Mr. Lawrence    male  34.0
# ..           ...                                           ...     ...   ...
# 866          867                  Duran y More, Miss. Asuncion  female  27.0
# 874          875         Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 880          881  Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0
# 883          884                 Banfield, Mr. Frederick James    male  28.0
# 886          887                         Montvila, Rev. Juozas    male  27.0
#
#      Survived  Pclass            Ticket     Fare
# 9           1       2            237736  30.0708
# 15          1       2            248706  16.0000
# 17          1       2            244373  13.0000
# 20          0       2            239865  26.0000
# 21          1       2            248698  13.0000
# ..        ...     ...               ...      ...
# 866         1       2     SC/PARIS 2149  13.8583
# 874         1       2         P/PP 3381  24.0000
# 880         1       2            230433  26.0000
# 883         0       2  C.A./SOTON 34068  10.5000
# 886         0       2            211536  13.0000
#
# [163 rows x 8 columns]

# %% [markdown]
# ### Ejercicio 6:
# - Del resultado anterior obten el número de hombres y el número de mujeres.

# %%
ej5.value_counts("Sex")
# Out:
# Sex
# male      95
# female    68
# dtype: int64

# %%
ej5.groupby("Sex").size()
# Out:
# Sex
# female    68
# male      95
# dtype: int64

# %% [markdown]
# ### Ejercicio 7:
# - Obten el costo total de los tickets de hombres y el costo total de los tickets de mujeres.

# %%
df[df["Sex"] == "male"]["Fare"].sum()
# Out:
# 14727.286500000002

# %%
df[df["Sex"] == "female"]["Fare"].sum()
# Out:
# 13966.6628

# %%
df.groupby("Sex").sum()["Fare"]
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %% [markdown]
# ### Ejercicio 8:
# - Obten el costo total de los tickets por cada clase (1, 2 y 3) y el número de pasajeros de cada clase.

# %%
print(df[df["Pclass"] == 1]["Fare"].sum())
print(df[df["Pclass"] == 1]["Fare"].shape[0])
# Out:
# 18177.4125
# 216

# %%
print(df[df["Pclass"] == 2]["Fare"].sum())
print(df[df["Pclass"] == 2]["Fare"].shape[0])
# Out:
# 3801.8417
# 184

# %%
print(df[df["Pclass"] == 3]["Fare"].sum())
print(df[df["Pclass"] == 3]["Fare"].shape[0])
# Out:
# 6714.6951
# 491

# %%
for i in df["Pclass"].unique():
    print(i)
    print(df[df["Pclass"] == i]["Fare"].sum())
    print(df[df["Pclass"] == i]["Fare"].shape[0])
    print("-"*20)
# Out:
# 3
# 6714.6951
# 491
# --------------------
# 1
# 18177.4125
# 216
# --------------------
# 2
# 3801.8417
# 184
# --------------------

# %%
df.groupby("Pclass").agg({"Fare" : ["sum", "count"]})
# Out:
#               Fare
#                sum count
# Pclass
# 1       18177.4125   216
# 2        3801.8417   184
# 3        6714.6951   491

# %% [markdown]
# ### Ejercicio 9:
# - Crear una columna con el apellido de cada pasajero y agregala al DataFrame.

# %%
df["Surname"] = df["Name"].map(lambda x : x.split(",")[0])

# %%
df
# Out:
#      PassengerId                                               Name     Sex  \
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
#       Age  Survived  Pclass            Ticket     Fare    Surname
# 0    22.0         0       3         A/5 21171   7.2500     Braund
# 1    38.0         1       1          PC 17599  71.2833    Cumings
# 2    26.0         1       3  STON/O2. 3101282   7.9250  Heikkinen
# 3    35.0         1       1            113803  53.1000   Futrelle
# 4    35.0         0       3            373450   8.0500      Allen
# ..    ...       ...     ...               ...      ...        ...
# 886  27.0         0       2            211536  13.0000   Montvila
# 887  19.0         1       1            112053  30.0000     Graham
# 888   NaN         0       3        W./C. 6607  23.4500   Johnston
# 889  26.0         1       1            111369  30.0000       Behr
# 890  32.0         0       3            370376   7.7500     Dooley
#
# [891 rows x 9 columns]

# %% [markdown]
# ### Ejercicio 10:
# - Encuentra si se repiten apellidos en la columna que se creo en el ejercicio anterior. (Usa .value_counts())

# %%
df["Surname"].value_counts()
# Out:
# Andersson    9
# Sage         7
# Panula       6
# Skoog        6
# Carter       6
#             ..
# Hanna        1
# Lewy         1
# Mineff       1
# Haas         1
# Dooley       1
# Name: Surname, Length: 667, dtype: int64

# %% [markdown]
# ### Ejercicio 11:
# - Encuentra los apellidos que se repiten en la columna recien creada. Es decir, solo muestra los apellidos que aparecen más de 1 vez.

# %%
df[df["Surname"].duplicated()]
# Out:
#      PassengerId                                      Name     Sex   Age  \
# 24            25             Palsson, Miss. Torborg Danira  female   8.0
# 38            39        Vander Planke, Miss. Augusta Maria  female  18.0
# 68            69           Andersson, Miss. Erna Alexandra  female  17.0
# 71            72                Goodwin, Miss. Lillian Amy  female  16.0
# 88            89                Fortune, Miss. Mabel Helen  female  23.0
# ..           ...                                       ...     ...   ...
# 876          877             Gustafsson, Mr. Alfred Ossian    male  20.0
# 877          878                      Petroff, Mr. Nedelio    male  19.0
# 885          886      Rice, Mrs. William (Margaret Norton)  female  39.0
# 887          888              Graham, Miss. Margaret Edith  female  19.0
# 888          889  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
#
#      Survived  Pclass      Ticket      Fare        Surname
# 24          0       3      349909   21.0750        Palsson
# 38          0       3      345764   18.0000  Vander Planke
# 68          1       3     3101281    7.9250      Andersson
# 71          0       3     CA 2144   46.9000        Goodwin
# 88          1       1       19950  263.0000        Fortune
# ..        ...     ...         ...       ...            ...
# 876         0       3        7534    9.8458     Gustafsson
# 877         0       3      349212    7.8958        Petroff
# 885         0       3      382652   29.1250           Rice
# 887         1       1      112053   30.0000         Graham
# 888         0       3  W./C. 6607   23.4500       Johnston
#
# [224 rows x 9 columns]

# %%
df["Surname"][df["Surname"].duplicated()].unique
# Out:
# array(['Palsson', 'Vander Planke', 'Andersson', 'Goodwin', 'Fortune',
#        'Moran', 'Turpin', 'Nasser', 'White', 'Nicola-Yarred', 'Futrelle',
#        'Ford', 'Williams', 'Panula', 'Skoog', 'Rice', 'Johnson', 'Sage',
#        'Asplund', 'Navratil', 'Olsen', 'Backstrom', 'Harris', 'Lefebre',
#        'Zabour', 'Attalah', 'Strom', 'Smith', 'Baxter', 'Allison',
#        'Kantor', 'Caldwell', 'Goldsmith', 'McCoy', 'Graham', 'Pears',
#        'Brown', 'Arnold-Franchi', "O'Brien", 'Meyer', 'Gustafsson',
#        'Holverson', 'Carter', 'Newell', 'Sandstrom', 'Johansson',
#        'Olsson', 'Jussila', 'Hakkarainen', 'Hart', 'Minahan', 'Rosblom',
#        'Richards', 'Mellinger', 'West', 'Baclini', 'Braund', 'Bishop',
#        'Hoyt', 'Coutts', 'Hagland', 'Calic', 'Penasco y Castellana',
#        'Webber', 'Hippach', 'Quick', 'Elias', 'Peter', 'Cacic', 'Beane',
#        'Davies', 'Taussig', 'Flynn', 'Kelly', 'Silvey', 'Thayer',
#        'Bourke', 'Van Impe', 'Boulos', 'Duff Gordon', 'Jacobsohn',
#        'Laroche', 'Murphy', 'Danbom', 'Lobb', 'Becker', 'Nakid',
#        'Collyer', 'Thorneycroft', 'Harper', 'Stanley', 'Doling',
#        'Hickman', 'Frauenthal', 'Coleff', 'Chapman', 'Barbara', 'Hansen',
#        'Morley', 'Moubarek', 'Taylor', 'Larsson', 'Jensen', 'Oreskovic',
#        'Renouf', 'Allen', 'Ryerson', 'Crosby', 'Abbott', 'Herman',
#        'Hamalainen', 'Hocking', 'Dick', 'Ali', 'Dean', 'Keane', 'Andrews',
#        'Chambers', 'Hays', 'Moor', 'Lam', 'Mallet', 'Yasbeck', 'Saad',
#        'Goldenberg', 'Svensson', 'Wick', 'Daly', 'Beckwith', 'Carlsson',
#        'Abelson', 'Petroff', 'Johnston'], dtype=object)

# %% [markdown]
# ### Ejercicio 12:
# - Imprime los primeros 10 pasajeros que tengan un **`PassengerID`** multiplo de 3.

# %%
df[df["PassengerId"].isin(range(3, 31, 3))].head(10)
# Out:
#     PassengerId                                               Name     Sex  \
# 2             3                             Heikkinen, Miss. Laina  female
# 5             6                                   Moran, Mr. James    male
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 14           15               Vestrom, Miss. Hulda Amanda Adolfina  female
# 17           18                       Williams, Mr. Charles Eugene    male
# 20           21                               Fynney, Mr. Joseph J    male
# 23           24                       Sloper, Mr. William Thompson    male
# 26           27                            Emir, Mr. Farred Chehab    male
# 29           30                                Todoroff, Mr. Lalio    male
#
#      Age  Survived  Pclass            Ticket     Fare    Surname
# 2   26.0         1       3  STON/O2. 3101282   7.9250  Heikkinen
# 5    NaN         0       3            330877   8.4583      Moran
# 8   27.0         1       3            347742  11.1333    Johnson
# 11  58.0         1       1            113783  26.5500    Bonnell
# 14  14.0         0       3            350406   7.8542    Vestrom
# 17   NaN         1       2            244373  13.0000   Williams
# 20  35.0         0       2            239865  26.0000     Fynney
# 23  28.0         1       1            113788  35.5000     Sloper
# 26   NaN         0       3              2631   7.2250       Emir
# 29   NaN         0       3            349216   7.8958   Todoroff

# %% [markdown]
# ### Ejercicio 13:
# - ¿Cuales son los apellidos de los pasajeros que son mujeres y menores de 20 años?

# %%
df[(df["Sex"] == "female") & (df["Age"] < 20)]
# Out:
#      PassengerId                                  Name     Sex   Age  \
# 9             10   Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10            11       Sandstrom, Miss. Marguerite Rut  female   4.0
# 14            15  Vestrom, Miss. Hulda Amanda Adolfina  female  14.0
# 22            23           McGowan, Miss. Anna "Annie"  female  15.0
# 24            25         Palsson, Miss. Torborg Danira  female   8.0
# ..           ...                                   ...     ...   ...
# 852          853               Boulos, Miss. Nourelain  female   9.0
# 853          854             Lines, Miss. Mary Conover  female  16.0
# 855          856            Aks, Mrs. Sam (Leah Rosen)  female  18.0
# 875          876      Najib, Miss. Adele Kiamie "Jane"  female  15.0
# 887          888          Graham, Miss. Margaret Edith  female  19.0
#
#      Survived  Pclass    Ticket     Fare    Surname
# 9           1       2    237736  30.0708     Nasser
# 10          1       3   PP 9549  16.7000  Sandstrom
# 14          0       3    350406   7.8542    Vestrom
# 22          1       3    330923   8.0292    McGowan
# 24          0       3    349909  21.0750    Palsson
# ..        ...     ...       ...      ...        ...
# 852         0       3      2678  15.2458     Boulos
# 853         1       1  PC 17592  39.4000      Lines
# 855         1       3    392091   9.3500        Aks
# 875         1       3      2667   7.2250      Najib
# 887         1       1    112053  30.0000     Graham
#
# [75 rows x 9 columns]

# %%
apellidos_mujeres = df["Surname"][(df["Sex"] == "female") & (df["Age"] < 20)].unique()

# %%
apellidos_mujeres
# Out:
# array(['Nasser', 'Sandstrom', 'Vestrom', 'McGowan', 'Palsson',
#        'Vander Planke', 'Nicola-Yarred', 'Laroche', 'Devaney',
#        'Arnold-Franchi', 'West', 'Andersson', 'Goodwin', 'Ilett',
#        'Zabour', 'Attalah', 'Newsom', 'Ford', 'Gilnagh', 'Johnson',
#        'Kink-Heilmann', 'Andersen-Jensen', 'Strom', 'Carr', 'Asplund',
#        'Collyer', 'Bishop', 'Allison', 'Penasco y Castellana', 'Ryerson',
#        'Hippach', 'Nakid', 'Lehmann', 'Silven', 'Van Impe', 'Phillips',
#        'Carter', 'Mellinger', 'Baclini', 'Hirvonen', 'Maioni', 'Quick',
#        'Hart', 'Beane', 'Taussig', 'Becker', 'Skoog', 'Doling', 'Hegarty',
#        'Turja', 'Madill', 'Karun', 'Astor', 'Barbara', 'Harper', 'Wells',
#        'Emanuel', 'Ayoub', 'Dick', 'Sjoblom', 'Pettersson', 'Yasbeck',
#        'Boulos', 'Lines', 'Aks', 'Najib', 'Graham'], dtype=object)

# %% [markdown]
# ### Ejercicio 14:
# - ¿Cuales son los apellidos de los pasajeros que son hombres y mayor de 45 años?

# %%
df[(df["Sex"] == "male") & (df["Age"] > 45)]
# Out:
#      PassengerId                            Name   Sex   Age  Survived  \
# 6              7         McCarthy, Mr. Timothy J  male  54.0         0
# 33            34           Wheadon, Mr. Edward H  male  66.0         0
# 54            55  Ostby, Mr. Engelhart Cornelius  male  65.0         0
# 92            93     Chaffee, Mr. Herbert Fuller  male  46.0         0
# 94            95               Coxon, Mr. Daniel  male  59.0         0
# ..           ...                             ...   ...   ...       ...
# 771          772         Jensen, Mr. Niels Peder  male  48.0         0
# 789          790        Guggenheim, Mr. Benjamin  male  46.0         0
# 851          852             Svensson, Mr. Johan  male  74.0         0
# 857          858          Daly, Mr. Peter Denis   male  51.0         1
# 873          874     Vander Cruyssen, Mr. Victor  male  47.0         0
#
#      Pclass       Ticket     Fare          Surname
# 6         1        17463  51.8625         McCarthy
# 33        2   C.A. 24579  10.5000          Wheadon
# 54        1       113509  61.9792            Ostby
# 92        1  W.E.P. 5734  61.1750          Chaffee
# 94        3       364500   7.2500            Coxon
# ..      ...          ...      ...              ...
# 771       3       350047   7.8542           Jensen
# 789       1     PC 17593  79.2000       Guggenheim
# 851       3       347060   7.7750         Svensson
# 857       1       113055  26.5500             Daly
# 873       3       345765   9.0000  Vander Cruyssen
#
# [73 rows x 9 columns]

# %%
apellidos_hombres = df["Surname"][(df["Sex"] == "male") & (df["Age"] > 45)].unique()

# %%
apellidos_hombres
# Out:
# array(['McCarthy', 'Wheadon', 'Ostby', 'Chaffee', 'Coxon', 'Goldschmidt',
#        'Porter', 'Connors', 'White', 'Bateman', 'Meo', 'Williams',
#        'Van der hoef', 'Smith', 'Youseff', 'Green', 'Sjostedt', 'Carter',
#        'Stead', 'Taussig', 'Duane', 'Moraweck', 'Nysveen', 'Partner',
#        'McKane', 'Widegren', 'Silvey', 'Fortune', 'Peuchen', 'Goldenberg',
#        'Millet', 'Anderson', 'Gee', 'Milling', 'Smart', 'Rouse', 'Kent',
#        'Molson', 'Artagaveytia', 'Walker', 'Douglas', 'Nicholson',
#        'Wright', 'Harris', 'Downton', 'Jarvis', 'Frolicher-Stehli',
#        'Elsbury', 'Johnson', 'Duff Gordon', 'Sutton', 'Kirkland',
#        'Barkworth', 'Lundahl', 'Harper', 'Simonius-Blumer', 'Newell',
#        'Frauenthal', 'Colley', 'Mitchell', 'Brown', 'Weir', 'Chapman',
#        'Thayer', 'Taylor', 'Greenberg', 'Hodges', 'Crosby', 'Jensen',
#        'Guggenheim', 'Svensson', 'Daly', 'Vander Cruyssen'], dtype=object)

# %% [markdown]
# ### Ejercicio 15:
# - Compara si coinciden los apellidos generados en los ejercicios anteriores.

# %%
apellidos_mujeres
apellidos_hombres

# %% [markdown]
# ### Ejercicio 16:
# - Encuentra los 10 pasajeros que no sobrevivieron más jovenes e imprime cuantos son hombres y cuantos son mujeres.

# %%
df[(df["Survived"] == 0)].sort_values("Age").head(10).value_counts("Sex")
# Out:
# Sex
# female    5
# male      5
# dtype: int64

# %% [markdown]
# ### Ejercicio 17:
# -  En un dataFrame muestra 3 pasajeros que sean hombres y 3 que sean mujeres, que hayan sobrevivido y para cada clase de la columna Pclass.

# %%
df[df["Survived"] == 1].groupby(["Pclass", "Sex"]).head(3).sort_values(["Pclass", "Sex"])
# Out:
#     PassengerId                                               Name     Sex  \
# 1             2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3             4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 11           12                           Bonnell, Miss. Elizabeth  female
# 23           24                       Sloper, Mr. William Thompson    male
# 55           56                                  Woolner, Mr. Hugh    male
# 97           98                    Greenfield, Mr. William Bertram    male
# 9            10                Nasser, Mrs. Nicholas (Adele Achem)  female
# 15           16                   Hewlett, Mrs. (Mary D Kingcome)   female
# 43           44           Laroche, Miss. Simonne Marie Anne Andree  female
# 17           18                       Williams, Mr. Charles Eugene    male
# 21           22                              Beesley, Mr. Lawrence    male
# 78           79                      Caldwell, Master. Alden Gates    male
# 2             3                             Heikkinen, Miss. Laina  female
# 8             9  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10           11                    Sandstrom, Miss. Marguerite Rut  female
# 36           37                                   Mamee, Mr. Hanna    male
# 65           66                           Moubarek, Master. Gerios    male
# 74           75                                      Bing, Mr. Lee    male
#
#       Age  Survived  Pclass            Ticket     Fare     Surname
# 1   38.00         1       1          PC 17599  71.2833     Cumings
# 3   35.00         1       1            113803  53.1000    Futrelle
# 11  58.00         1       1            113783  26.5500     Bonnell
# 23  28.00         1       1            113788  35.5000      Sloper
# 55    NaN         1       1             19947  35.5000     Woolner
# 97  23.00         1       1          PC 17759  63.3583  Greenfield
# 9   14.00         1       2            237736  30.0708      Nasser
# 15  55.00         1       2            248706  16.0000     Hewlett
# 43   3.00         1       2     SC/Paris 2123  41.5792     Laroche
# 17    NaN         1       2            244373  13.0000    Williams
# 21  34.00         1       2            248698  13.0000     Beesley
# 78   0.83         1       2            248738  29.0000    Caldwell
# 2   26.00         1       3  STON/O2. 3101282   7.9250   Heikkinen
# 8   27.00         1       3            347742  11.1333     Johnson
# 10   4.00         1       3           PP 9549  16.7000   Sandstrom
# 36    NaN         1       3              2677   7.2292       Mamee
# 65    NaN         1       3              2661  15.2458    Moubarek
# 74  32.00         1       3              1601  56.4958        Bing

# %% [markdown]
# ### Ejercicio 18:
# - Obtener el tipo de elementos de cada columna y convierte los que sean "int64" a "int32". Evalua la memoria que consume antes y después de convertir las columnas y comenta la diferencia.

# %%
diccionario = df.dtypes.to_dict()
diccionario
# Out:
# {'PassengerId': dtype('int64'),
#  'Name': dtype('O'),
#  'Sex': dtype('O'),
#  'Age': dtype('float64'),
#  'Survived': dtype('int64'),
#  'Pclass': dtype('int64'),
#  'Ticket': dtype('O'),
#  'Fare': dtype('float64'),
#  'Surname': dtype('O')}

# %%
for llave, valor in diccionario.items():
    if valor == "int64":
        df[llave]

# %% [markdown]
# ### Ejercicio 19:
# - Encuentra a los pasajeros de la clase 1 y 3 entre 20 y 25 años y comprueba si son más hombres o mujeres.

# %% [markdown]
# ### Ejercicio 20:
# - Agrega una nueva columna al DataFrame que se llame: "Rango edad" y va a categorizar de la siguiente manera:
#     - Niño < 11 años
#     - Joven < 18 años
#     - Adulto < 50 años
#     - Mayor >= 50 años

# %% [markdown]
# ### Ejercicio 21:
# - Encontrar a los pasajeros "jovenes" y "mayores" de la clase 2 y 3 que hayan sobrevivido. Imprimir los 10 primeros.

# %% [markdown]
# ### Ejercicio 22:
# - Encuentra la edad promedio de todos los pasajeros y reemmplazala por los NaN en la columna de Age y ejecuta el ejercicio anterior.

# %% [markdown]
# ### Ejercicio 23:
# - Cambia a español la columna **`Sex`**.

# %% [markdown]
# ### Ejercicio 24:
# - Convierte a mayusculas todas las columnas que los valores sean cadenas.

# %% [markdown]
# ### Ejercicio 25:
# - Agrupa por sexo y rango de edad y encuentra la edad promedio.

# %% [markdown]
# ### Ejercicio 26:
# - Divide la columna name en las siguientes columnas:
#     - Mrs/Miss
#     - Apellido
#     - Nombre(s)
#
# **Nota: Ignora el resto de información.**
