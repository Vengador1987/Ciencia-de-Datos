# %% [markdown]
# # Web Scraping con bs4 (BeautifulSoup)
#
# **`BeautifulSoup`** es una biblioteca de python para extraer contenido de ficheros **`HTML`** y **`XML`**.
#
# **`requests`** es una libreria que maneja los **requests** (o peticiones) de **HTTP** de una forma sencilla.
#
# **`bs4 : pip install beautifulsoup4`**
#
# **`requests : pip install requests`**
#
# Primero usamos **`requests`** para tener "acceso" a las páginas web, luego usamos **`BeautifulSoup`** para extraer la información del **`HTML`**.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### requests
#
# **`requests.get()`** toma un **`url`** (o enlace) y retorna la **"respuesta"** del servidor. Este nuevo objeto también extrae el código **`HTML`** del **`url`**.
#
# **ADVERTENCIA: CADA "REQUEST" TOMA UN TIEMPO DE RESPUESTA, POR LO QUE SI INTENTAMOS HACER MUCHOS "REQUESTS" EN UN PLAZO CORTO DE TIEMPO NUESTRO IP SERÁ BANEADO DE LA PAGINA WEB PARA EVITAR COLAPSAR LA PÁGINA WEB. EN EL PEOR DE LOS CASOS LA PÁGINA RECIBIRÁ TANTOS "REQUESTS" QUE COLAPSARÁ Y LA DEJAREMOS FUERA DE SERVICIO.**

# %%
url = "https://google.com/"

response = requests.get(url)


print(response)

print(bool(response))
# Out:
# <Response [200]>
# True

# %%
# El atributo .text retorna el HTML de la página 

print(response.text)
# Out:
# <!DOCTYPE html><html lang="es" dir="ltr"><head><style nonce="y/XZVCVmyGnBa6EX6jmB5Q">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 520px;
#   padding: 24px;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# p, .sub, .contentText {
#   color: #5f6368;;
#   font-size: 14px;
#   line-height: 20px;
#   letter-spacing: 0.2px;
#   text-align: left;
# }
# .signin {
#   text-align: right;
# }
# .image {
#   display: block;
#   margin: 14px auto;
# }
# .basebutton {
#   border-radius: 4px;
#   cursor: pointer;
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   font-size: 14px;
#   font-weight: 500;
#   height: 36px;
#   margin: 12px 4px 0;
#   padding: 10px 24px;
# }
# a.button {
#   color: #fff;
# }
# button, .button {
#   background-color: #1a73e8;
#   border: none;
#   color: #fff;
# }
# input.button {
#   -webkit-appearance: none;
# }
# .error {
#   border: 2px solid #d93025;
#   border-radius: 5px;
#   color: #d93025;
#   margin: auto;
#   padding: 5px;
# }
# .footer {
#   margin-top: 16px;
# }
# .footer a {
#   margin-left: 24px;
#   white-space: nowrap;
# }
# .footer a, .footer select, .footer input {
#   color: #757575;
#   font-size: 12px;
# }
# .languagepicker {
#   display: inline-flex;
#   margin: 2px 0;
# }
# #languageform,
# #languageselect {
#   margin: 0 2px;
# }
# #languageselect {
#   color: #757575;
# }
# .detailspage {
#   margin: 24px auto 0 auto;
#   max-width: 700px;
# }
# .detailspage h1, .detailspage h2 {
#   font-size: 22px
# }
# .setting {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin-bottom: 11px;
#   padding: 24px 24px 20px 24px;
#   text-align: right;
# }
# .sub {
#   padding: 24px 24px 20px 24px;
# }
# hr {
#   margin: 12px -24px 12px;
#   border: 0;
#   border-top: 1px solid #dadce0;
# }
# fieldset {
#   border: none;
#   padding: 0;
# }
# label {
#   margin: 24px;
# }
# td {
#   vertical-align: top;
# }
# .setting h2, .setting h3, h4 {
#   color: #3c4043;
#   margin: 0;
#   text-align: left;
# }
# .yt-text {
#   color: #5f6368;
#   font-size: 14px;
#   font-weight: 300;
# }
# .productLogoContainer {
#   margin: auto;
#   max-width: 360px;
# }
#
# /** Narrow screen (for example a mobile device). */
# @media only screen and (max-width: 480px) {
#   body {
#     margin: 18px 14px;
#   }
#   .imgContainer {
#     min-width: 96px;
#   }
#   .hideOnSmallWidth {
#     display: none;
#   }
#   .footer form {
#     margin-bottom: 3px;
#   }
# }
#
# @media only screen and (max-width: 380px) {
#   .imgContainer {
#     min-width: 72px;
#   }
# }
#
# /** Normal/non-narrow screen. */
# @media not screen and (max-width: 480px) {
#   body {
#     margin: 18px 25px;
#   }
#   .imgContainer {
#     width: 51%;
#   }
#   .hideOnNormalWidth {
#     display: none;
#   }
#   .footer form {
#     display: inline;
#   }
# }
# </style><title>Antes de ir a la Búsqueda de Google</title><meta name="viewport" content="initial-scale=1, maximum-scale=5, width=device-width"><link rel="shortcut icon" href="//www.google.com/favicon.ico"></head><body><div class="signin"><a href="https://accounts.google.com/ServiceLogin?hl=es&amp;continue=https://www.google.com/&amp;gae=cb-" class="basebutton button">Iniciar sesión</a></div><div class="box"><img src="//www.gstatic.com/images/branding/googlelogo/1x/googlelogo_color_68x28dp.png" srcset="//www.gstatic.com/images/branding/googlelogo/2x/googlelogo_color_68x28dp.png 2x" width="68" height="28" alt="Google"><div class="productLogoContainer"><img src="https://www.gstatic.com/ac/cb/scene_cookie_wall_search_v2.svg" alt="" width="100%" height="100%" class="image" aria-hidden="true"></div><h1>Antes de ir a la Búsqueda de Google</h1><div class="contentText">En Google utilizamos <a href="https://policies.google.com/technologies/cookies?hl=es&utm_source=ucb" target="_blank">cookies</a> y datos para:<ul><li>Proporcionar y mantener servicios, como hacer un seguimiento de las interrupciones y prevenir el spam, el fraude y los abusos</li><li>Medir la interacción de la audiencia y estadísticas de los sitios para entender cómo se utilizan nuestros servicios</li></ul>Si aceptas, también usaremos las cookies y los datos para:<ul><li>Mejorar la calidad de nuestros servicios y desarrollar otros nuevos</li><li>Mostrar anuncios y medir su eficacia</li><li>Mostrar contenido personalizado en función de tus ajustes</li><li>Mostrar anuncios genéricos o personalizados, en función de tus ajustes, en Google y en la Web</li></ul>Con respecto al contenido y los anuncios no personalizados, lo que veas puede estar influido por factores como lo que estés viendo en ese momento y tu ubicación (el servicio de anuncios se basa en la ubicación general). El contenido y los anuncios personalizados se pueden basar, además de en esos criterios, en tu actividad, como las búsquedas que hagas en Google y los vídeos que veas en YouTube. Los anuncios y el contenido personalizados incluyen, entre otras cosas, resultados y recomendaciones más relevantes, una página de inicio de YouTube personalizada y anuncios adaptados a tus intereses.<p>Haz clic en Personalizar para ver las opciones disponibles, como los controles que permiten rechazar el uso de cookies para la personalización e información sobre los controles del navegador que permiten rechazar parte o la totalidad de las cookies para otros usos. También puedes visitar g.co/privacytools en cualquier momento.</p></div><div><a href="https://consent.google.com/dl?continue=https://www.google.com/&amp;gl=ES&amp;hl=es&amp;pc=shp&amp;src=1" class="basebutton button">Personalizar</a><form action="https://consent.google.com/s" method="POST" style="display:inline;"><input type="hidden" name="gl" value="ES"><input type="hidden" name="m" value="0"><input type="hidden" name="pc" value="shp"><input type="hidden" name="continue" value="https://www.google.com/"><input type="hidden" name="ca" value="r"><input type="hidden" name="x" value="8"><input type="hidden" name="v" value="cb.20220211-09-p0.es+FX+570"><input type="hidden" name="t" value="ADw3F8hNGBo30diW3Ncev1sSxmrlJc4RrA:1644999847468"><input type="hidden" name="hl" value="es"><input type="hidden" name="src" value="1"><input type="submit" value="Acepto" class="basebutton button" aria-label="Aceptar el uso de cookies y otros datos para las finalidades descritas"/></form></div></div><div class="footer"><form action="https://consent.google.com/ml" method="get"><select id="languageselect" name="hl"><option value="af">Afrikaans</option><option value="az">azərbaycan</option><option value="bs">bosanski</option><option value="ca">català</option><option value="cs">Čeština</option><option value="cy">Cymraeg</option><option value="da">Dansk</option><option value="de">Deutsch</option><option value="et">eesti</option><option value="en-GB">English&nbsp;(United Kingdom)</option><option v ...

# %% [markdown]
# ### BeautifulSoup
#
# Si la respuesta del **`requests`** es positiva podemos pasar este objeto **`requests.get()`** a **`BeautifulSoup`** para que nos ayude a filtrar la información y extraerla más fácil.
#
# Los métodos más comunes de **`BeautifulSoup`** son:
#
# |Método           |Descripción                                                                                        |
# |-----------------|---------------------------------------------------------------------------------------------------|
# |**`.body`**      | Retorna el contenido dentro de la etiqueta **`body`**.                                            |
# |**`.title`**     | Retorna el titulo del **HTML**.                                                                   |
# |**`.find()`**    | Busca en el **HTML** y retorna la primera ocurrencia del filtro en un objeto **`bs4`**.           |
# |**`.find_all()`**| Busca en el **HTML** y retorna todas las ocurrencias del filtro en una lista de objetos **`bs4`**.|
# |**`.text`**      | Retorna el texto de un objeto **`bs4`** en un **`str`**.                                          |

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="es"><head><style nonce="y/XZVCVmyGnBa6EX6jmB5Q">
# a, a:link, a:visited, a:active, a:hover {
#   color: #1a73e8;
#   text-decoration: none;
# }
# body {
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   text-align: center;
#   -ms-text-size-adjust: 100%;
#   -moz-text-size-adjust: 100%;
#   -webkit-text-size-adjust: 100%;
# }
# .box {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin: 24px auto 5px auto;
#   max-width: 520px;
#   padding: 24px;
# }
# h1 {
#   color: #2c2c2c;
#   font-size: 24px;
#   hyphens: auto;
#   margin: 24px 0;
# }
# p, .sub, .contentText {
#   color: #5f6368;;
#   font-size: 14px;
#   line-height: 20px;
#   letter-spacing: 0.2px;
#   text-align: left;
# }
# .signin {
#   text-align: right;
# }
# .image {
#   display: block;
#   margin: 14px auto;
# }
# .basebutton {
#   border-radius: 4px;
#   cursor: pointer;
#   font-family: Roboto,RobotoDraft,Helvetica,Arial,sans-serif;
#   font-size: 14px;
#   font-weight: 500;
#   height: 36px;
#   margin: 12px 4px 0;
#   padding: 10px 24px;
# }
# a.button {
#   color: #fff;
# }
# button, .button {
#   background-color: #1a73e8;
#   border: none;
#   color: #fff;
# }
# input.button {
#   -webkit-appearance: none;
# }
# .error {
#   border: 2px solid #d93025;
#   border-radius: 5px;
#   color: #d93025;
#   margin: auto;
#   padding: 5px;
# }
# .footer {
#   margin-top: 16px;
# }
# .footer a {
#   margin-left: 24px;
#   white-space: nowrap;
# }
# .footer a, .footer select, .footer input {
#   color: #757575;
#   font-size: 12px;
# }
# .languagepicker {
#   display: inline-flex;
#   margin: 2px 0;
# }
# #languageform,
# #languageselect {
#   margin: 0 2px;
# }
# #languageselect {
#   color: #757575;
# }
# .detailspage {
#   margin: 24px auto 0 auto;
#   max-width: 700px;
# }
# .detailspage h1, .detailspage h2 {
#   font-size: 22px
# }
# .setting {
#   border: 1px solid #dadce0;
#   box-sizing: border-box;
#   border-radius: 8px;
#   margin-bottom: 11px;
#   padding: 24px 24px 20px 24px;
#   text-align: right;
# }
# .sub {
#   padding: 24px 24px 20px 24px;
# }
# hr {
#   margin: 12px -24px 12px;
#   border: 0;
#   border-top: 1px solid #dadce0;
# }
# fieldset {
#   border: none;
#   padding: 0;
# }
# label {
#   margin: 24px;
# }
# td {
#   vertical-align: top;
# }
# .setting h2, .setting h3, h4 {
#   color: #3c4043;
#   margin: 0;
#   text-align: left;
# }
# .yt-text {
#   color: #5f6368;
#   font-size: 14px;
#   font-weight: 300;
# }
# .productLogoContainer {
#   margin: auto;
#   max-width: 360px;
# }
#
# /** Narrow screen (for example a mobile device). */
# @media only screen and (max-width: 480px) {
#   body {
#     margin: 18px 14px;
#   }
#   .imgContainer {
#     min-width: 96px;
#   }
#   .hideOnSmallWidth {
#     display: none;
#   }
#   .footer form {
#     margin-bottom: 3px;
#   }
# }
#
# @media only screen and (max-width: 380px) {
#   .imgContainer {
#     min-width: 72px;
#   }
# }
#
# /** Normal/non-narrow screen. */
# @media not screen and (max-width: 480px) {
#   body {
#     margin: 18px 25px;
#   }
#   .imgContainer {
#     width: 51%;
#   }
#   .hideOnNormalWidth {
#     display: none;
#   }
#   .footer form {
#     display: inline;
#   }
# }
# </style><title>Antes de ir a la Búsqueda de Google</title><meta content="initial-scale=1, maximum-scale=5, width=device-width" name="viewport"/><link href="//www.google.com/favicon.ico" rel="shortcut icon"/></head><body><div class="signin"><a class="basebutton button" href="https://accounts.google.com/ServiceLogin?hl=es&amp;continue=https://www.google.com/&amp;gae=cb-">Iniciar sesión</a></div><div class="box"><img alt="Google" height="28" src="//www.gstatic.com/images/branding/googlelogo/1x/googlelogo_color_68x28dp.png" srcset="//www.gstatic.com/images/branding/googlelogo/2x/googlelogo_color_68x28dp.png 2x" width="68"/><div class="productLogoContainer"><img alt="" aria-hidden="true" class="image" height="100%" src="https://www.gstatic.com/ac/cb/scene_cookie_wall_search_v2.svg" width="100%"/></div><h1>Antes de ir a la Búsqueda de Google</h1><div class="contentText">En Google utilizamos <a href="https://policies.google.com/technologies/cookies?hl=es&amp;utm_source=ucb" target="_blank">cookies</a> y datos para:<ul><li>Proporcionar y mantener servicios, como hacer un seguimiento de las interrupciones y prevenir el spam, el fraude y los abusos</li><li>Medir la interacción de la audiencia y estadísticas de los sitios para entender cómo se utilizan nuestros servicios</li></ul>Si aceptas, también usaremos las cookies y los datos para:<ul><li>Mejorar la calidad de nuestros servicios y desarrollar otros nuevos</li><li>Mostrar anuncios y medir su eficacia</li><li>Mostrar contenido personalizado en función de tus ajustes</li><li>Mostrar anuncios genéricos o personalizados, en función de tus ajustes, en Google y en la Web</li></ul>Con respecto al contenido y los anuncios no personalizados, lo que veas puede estar influido por factores como lo que estés viendo en ese momento y tu ubicación (el servicio de anuncios se basa en la ubicación general). El contenido y los anuncios personalizados se pueden basar, además de en esos criterios, en tu actividad, como las búsquedas que hagas en Google y los vídeos que veas en YouTube. Los anuncios y el contenido personalizados incluyen, entre otras cosas, resultados y recomendaciones más relevantes, una página de inicio de YouTube personalizada y anuncios adaptados a tus intereses.<p>Haz clic en Personalizar para ver las opciones disponibles, como los controles que permiten rechazar el uso de cookies para la personalización e información sobre los controles del navegador que permiten rechazar parte o la totalidad de las cookies para otros usos. También puedes visitar g.co/privacytools en cualquier momento.</p></div><div><a class="basebutton button" href="https://consent.google.com/dl?continue=https://www.google.com/&amp;gl=ES&amp;hl=es&amp;pc=shp&amp;src=1">Personalizar</a><form action="https://consent.google.com/s" method="POST" style="display:inline;"><input name="gl" type="hidden" value="ES"/><input name="m" type="hidden" value="0"/><input name="pc" type="hidden" value="shp"/><input name="continue" type="hidden" value="https://www.google.com/"/><input name="ca" type="hidden" value="r"/><input name="x" type="hidden" value="8"/><input name="v" type="hidden" value="cb.20220211-09-p0.es+FX+570"/><input name="t" type="hidden" value="ADw3F8hNGBo30diW3Ncev1sSxmrlJc4RrA:1644999847468"/><input name="hl" type="hidden" value="es"/><input name="src" type="hidden" value="1"/><input aria-label="Aceptar el uso de cookies y otros datos para las finalidades descritas" class="basebutton button" type="submit" value="Acepto"/></form></div></div><div class="footer"><form action="https://consent.google.com/ml" method="get"><select id="languageselect" name="hl"><option value="af">Afrikaans</option><option value="az">azərbaycan</option><option value="bs">bosanski</option><option value="ca">català</option><option value="cs">Čeština</option><option value="cy">Cymraeg</option><option value="da">Dansk</option><option value="de">Deutsch</option><option value="et">eesti</option><option value="en-GB">English (United Kingdom)</opt ...

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# filmaffinity

url = "https://www.filmaffinity.com/es/topcat.php?id=new_th_es"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup.body
# Out:
# <body>
# <script>
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#           ga('create', 'UA-74155504-1', 'auto');
#           ga('send', 'pageview');
#         </script>
# <div id="page-header">
# <div id="header-top">
# <div class="cpanel top-wrapper">
# <div id="logo-container">
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>
# </div><!-- logo-container -->
# <div id="topsearch">
# <form accept-charset="UTF-8" action="https://www.filmaffinity.com/es/search.php" method="get">
# <input id="top-search-input" name="stext" size="20" tabindex="1" type="text" value=""/>
# <i class="fas fa-times clear-search"></i>
# <label for="button-search">
# <i class="fas fa-search"></i>
# </label>
# <input id="button-search" type="submit" value=" "/>
# </form>
# <div class="advsearch"><a href="https://www.filmaffinity.com/es/advsearch.php">Búsqueda avanzada <i class="fas fa-angle-double-right"></i></a></div>
# </div><!-- topsearch -->
# <div id="user-login-container">
# <div id="login-register">
# <a class="sign-in" href="https://www.filmaffinity.com/es/login.php"><strong>Iniciar sesión</strong></a> / <a class="register" href="https://www.filmaffinity.com/es/register.php">Registrarse</a>
# </div>
# <div class="user-menu-wr">
# <ul>
# <li>
# <a href="https://www.filmaffinity.com/es/userratings.php?user_id=">
# <span class="ic-w"><i class="fa fa-ratings-fa"></i></span>
#                 Mis Votaciones        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/myreviews.php">
# <span class="ic-w"><i class="fa fa-reviews-fa"></i></span>
#             Críticas        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/mylists.php">
# <span class="ic-w"><i class="fa fa-list"></i></span>
#             Listas <span class="nbr-w">New</span>
# </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/myfriends.php">
# <span class="ic-w"><i class="fa fa fa-friends-fa"></i></span>
#             Amigos / Grupos        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/soulmates.php">
# <span class="ic-w"><i class="fa fa-soulmates-fa"></i></span>
#             Almas gemelas™        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/smsrec.php">
# <span class="ic-w"><i class="fa fa-heart"></i></span>
#                 Recomendaciones        </a>
# </li>
# <li class="user-prof-link">
# <a href="https://www.filmaffinity.com/es/mydata.php">
# <span class="ic-w"><i class="fa fa-address-card-o"></i></span>
#                 Datos personales        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/user-fav-theaters.php">
# <span class="ic-w"><i class="fa fa-ticket"></i></span>
#                 Cines favoritos            </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/tours.php">
# <span class="ic-w"><i class="fa fa-ratings-fa"></i></span>
#                 Votar los tours            </a>
# </li>
# <li class="lg-out-li">
# <a class="sign-out" href="#">
#                 Cerrar sesión            </a>
# </li>
# </ul>
# </div>
# </div><!-- user-login -container -->
# </div>
# </div>
# <div id="header-bottom">
# <div class="cpanel news-wrapper">
# <ul id="awardsmenu">
# <li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Últ. críticas</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=TRAILERS">Tráilers</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/rankings.php">Rankings FA <span class="tooltip-new">New</span></a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Nuevo Top FA <span class="tooltip-new">New</span></a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/best_2021.php">2021</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=2022films">2022</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/awards.php?award_id=goya&amp;year=2022">Premios Goya 2022</a></li><li class="sep">|</li>
# </ul>
# <div id="trmenu">
# <div class="social-logo" id="fb-top-logo"><a href="http://www.facebook.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Facebook (180.000 followers)"><i class="fab fa-facebook-f"></i></a></div>
# <div class="social-logo" id="tw-top-logo"><a href="http://twitter.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Twitter (60.000 followers)"><i class="fab fa-twitter"></i></a></div>
# <div class="social-logo" id="in-top-logo"><a href="https://www.instagram.com/filmaffinity/" target="_BLANK" title="Sigue a FA en Instagram (155.000 followers)"><i class="fab fa-instagram"></i></a></div>
# </div>
# <div class="version-selector">
# <ul class="version">
# <li class="fixed" data-version="es" title="Cambiar de versión">España <i class="fas fa-chevron-down"></i></li>
# </ul>
# </div>
# <div class="page-versions-pop fa-shadow">
# <div id="vmap" style="width: 630px; height: 400px;"></div>
# <div class="country-names">
# <ul class="continents">
# <li data-continent="america-north">
# <div class="header">Norteamérica <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="us" data-version="us"><img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/> US <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ca" data-version="ca"><img alt="Canadá" class="nflag" src="/imgs/countries2/CA.png"/> Canadá <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="mx" data-version="mx"><img alt="México" class="nflag" src="/imgs/countries2/MX.png"/> México <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="europe">
# <div class="header">Europa <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="es" data-version="es"><img alt="España" class="nflag" src="/imgs/countries2/ES.png"/> España <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gb" data-version="uk"><img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/> UK <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ie" data-version="ie"><img alt="Irlanda" class="nflag" src="/imgs/countries2/IE.png"/> Irlanda <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="oceania">
# <div class="header">Oceanía <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="au" data-version="au"><img alt="Australia" class="nflag" src="/imgs/countries2/AU.png"/> Australia <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <ul class="continents">
# <li data-continent="america-south">
# <div class="header">América del sur <i class="fas fa-search-plus map-zoom"></i> </div>
# <ul class="countries">
# <li data-country-id="ar" data-version="ar"><img alt="Argentina" class="nflag" src="/imgs/countries2/AR.png"/> Argentina <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cl" data-version="cl"><img alt="Chile" class="nflag" src="/imgs/countries2/CL.png"/> Chile <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="co" data-version="co"><img alt="Colombia" class="nflag" src="/imgs/countries2/CO.png"/> Colombia <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="uy" data-version="uy"><img alt="Uruguay" class="nflag" src="/imgs/countries2/UY.png"/> Uruguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="py" data-version="py"><img alt="Paraguay" class="nflag" src="/imgs/countries2/PY.png"/> Paraguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="pe" data-version="pe"><img alt="Perú" class="nflag" src="/imgs/countries2/PE.png"/> Perú <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ec" data-version="ec"><img alt="Ecuador" class="nflag" src="/imgs/countries2/EC.png"/> Ecuador <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ve" data-version="ve"><img alt="Venezuela" class="nflag" src="/imgs/countries2/VE.png"/> Venezuela <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cr" data-version="cr"><img alt="Costa Rica" class="nflag" src="/imgs/countries2/CR.png"/> Costa Rica <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="hn" data-version="hn"><img alt="Honduras" class="nflag" src="/imgs/countries2/HN.png"/> Honduras <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gt" data-version="gt"><img alt="Guatemala" class="nflag" src="/imgs/countries2/GT.png"/> Guatemala <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="bo" data-version="bo"><img alt="Bolivia" class="nflag" src="/imgs/countries2/BO.png"/> Bolivia <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <a class="more-info" href="https://www.filmaffinity.com/es/fa-international.php"><i class="fas fa-info-circle"></i> Más información</a>
# </div>
# </div>
# <script type="text/javascript">
#
#     var mapVersions = {"us":"#3C6E99","ca":"#3C6E99","mx":"#3C6E99","es":"#3C6E99","gb":"#3C6E99","ie":"#3C6E99","au":"#3C6E99","ar":"#3C6E99","cl":"#3C6E99","co":"#3C6E99","uy":"#3C6E99","py":"#3C6E99","pe":"#3C6E99","ec":"#3C6E99","ve":"#3C6E99","cr":"#3C6E99","hn":"#3C6E99","gt":"#3C6E99","bo":"#3C6E99"};
#
# /*  //para sacar trazas de coordenadas.
#     jQuery('#vmap').on('drag', function(event)
#     {
#         console.log(jqvmap.transX);
#         console.log(jqvmap.transY);
#         console.log(jqvmap.scale);
#         console.log(jqvmap.zoomCurStep);
#     });
# */
#
#
# </script>
# </div>
# </div>
# </div>
# <div class="cpanel adver-wrapper">
# <div class="adver-fix" id="top-ad">
# <div class="sc-top" id="sc-top">
# <script>
#
#                   googletag.cmd.push(function() {
#
#                         googletag.display('sc-top');
#
#                  });
#
#            </script>
# </div>
# <!-- sc-oop-->
# <div class="sc-oop" id="sc-oop">
# <script>
#
#                  googletag.cmd.push(function() {
#
#                         googletag.display('sc-oop');
#
#                  });
#
#            </script>
# </div>
# </div>
# </div>
# <div id="top-anch">
# <a href="#header-top" title="Ir arriba">
# <img alt="arrow" src="https://www.filmaffinity.com/images/arrow-up2.png"/>
# </a>
# </div>
# <div class="cpanel">
# <table id="main-content-table">
# <tr>
# <td id="mt-left-cell">
# <div id="lsmenu">
# <div class="cat-container">
# <div class="lsmheader">Usuarios</div>
# <ul>
# <li><a class="rate-tours" href="https://www.filmaffinity.com/es/tours.php">Votar los tours</a></li><li><a class="sign-in" href="https://www.filmaffinity.com/es/login.php">Iniciar sesión</a></li><li><a href="https://www.filmaffinity.com/es/register.php">Registrarse</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">España</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Películas en cartelera</a></li><li><a href="https://www.filmaffinity.com/es/cityTheaters.php">Cines España</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">Próximos estrenos</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_sa_es.html">Estrenos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_sa_es">Próximos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_re_es.html">Ya para alquilar</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_re_es">Próximamente alquiler</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_netflix.html">Netflix</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_netflix">Netflix (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_movistar_f.html">Movistar + </a></li><li><a href="https://www.filmaffinity.com/es/cat_upc_movistar_f.html">Movistar + (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_hbo_es.html">HBO Max</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_filmin.html">Filmin</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_rakuten.html">Rakuten TV</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_amazon_es.html">Amazon Prime</a></li><li><a href="https://www.filmaffinity.com/es/cat_disneyplus.html">Disney+</a></li><li><a href="https://www.filmaffinity.com/es/cat_apple_tv_plus.html">Apple TV+</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">USA - UK - FR</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_us.html">Estrenos USA</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_uk.html">Estrenos Reino Unido</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_fr.html">Estrenos Francia</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Rankings FA</div>
# <ul>
# <li style="position: relative;"><strong><a class="Rankings" href="https://www.filmaffinity.com/es/rankings.php">Todos los rankings</a></strong><div id="tooltip-new-menu" style="background: linear-gradient(to bottom, #FFA84C 52%, #FF7B0D 100%) repeat scroll 0 0 rgba(0, 0, 0, 0); border-radius: 5px; color: #FFFFFF; font-size: 11px; line-height: 0.8; padding: 2px 3px; position: absolute; right: 2px; text-shadow: 0.2em 0.2em 0.2em #BBBBBB; bottom: 2px; font-style: italic;"><strong>N</strong></div></li><li><a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fa_movies">El Top 1000 de FA</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Secciones</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/boxoffice.php">Taquilla</a></li><li><a href="https://www.filmaffinity.com/es/trailers.php">Trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestevideos.php">Últimos trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestreviews.php">Últimas críticas users</a></li><li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Qué dice la crítica</a></li><li><a href="https://www.filmaffinity.com/es/topics.php">Películas por temas</a></li><li><a href="https://www.filmaffinity.com/es/movie-groups-all.php">Sagas &amp; Franquicias</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Series de TV</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_current_tv.html">Series de actualidad</a></li><li><a href="https://www.filmaffinity.com/es/topgen.php?genres=-DO&amp;chv=1&amp;orderby=avg&amp;movietype=serie%7Conly-serie&amp;country=&amp;fromyear=1874&amp;toyear=2021&amp;ratingcount=3&amp;runtimemin=0&amp;runtimemax=4">Top series</a></li><li><a href="https://www.filmaffinity.com/es/tour.php?idtour=26">Vota Series de TV</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">TOPs</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Top Filmaffinity</a></li><li><a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del TOP</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_th_es.html">Top Estrenos</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_sa_es.html">Top Estrenos Blu-ray</a></li><li><a href="https://www.filmaffinity.com/es/listsrank.php">Ranking de listas</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Premios | Festivales</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios y Festivales</a></li><li><a href="https://www.filmaffinity.com/es/oscar_data.php">Todos los Oscar</a></li><li><a href="https://www.filmaffinity.com/es/best_2021.php">Resumen 2021</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Información</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/site-guide.php">Acerca de FA</a></li><li><a href="https://www.filmaffinity.com/es/contact_us.php">Contacto</a></li></ul></div>
# </div>
# </td>
# <td>
# <div id="mt-content-cell">
# <div id="sh-pos-abs">
# <div class="sh-header" title="compartir"><i class="fas fa-share-alt"></i></div>
# </div>
# <style>
#     #hidden-url {position: absolute; left: 65px; top: 2px; display: none; padding: 2px 6px 4px 6px; background: #fdcc1a; margin-top: 5px; width: 485px; border-radius: 5px; animation-duration: .3s; z-index: 100;}
#     #hidden-url input{ font-size: 14px; font-weight: bold; outline: none; border: 1px solid #DDDDDD; border-radius: 5px; padding: 8px 4px; width: 435px; margin-left: 5px; font-family: monospace;}
#     #hidden-url .hide-url {cursor: pointer; font-size: 22px; margin: 0 5px; color: #000; vertical-align: middle;}
#     #copy-clipboard {position: absolute; left: 0px; top: 31px; padding: 2px 6px; background: #fdcc1a; margin-top: 5px; animation-duration: .3s; border-bottom-right-radius: 4px; border-bottom-left-radius: 4px; width: 200px; cursor: pointer; padding-left: 15px;}
# </style>
# <script>
#
#     function hideOnClick( ){
#         $(document).click(function(event) {
#             if(!$(event.target).closest('.hd-sh-wrapper').length && !$(event.target).closest('#hidden-url').length) {
#                 if($('.hd-sh-wrapper').is(":visible")) {
#                     //$('.hidden-share-wrapper').hide();
#                     $('.sh-header').trigger('click');
#                 }
#             }
#         });
#     }
#
#     $(function() {
#         $('.hd-sh-wrapper').bind('animationEnd oAnimationEnd msAnimationEnd mozAnimationEnd webkitAnimationEnd', function(event){
#             if(  $(event.target).hasClass('nkoout') )
#             {
#                 $('.hd-sh-wrapper').hide();
#             }
#
#         });
#
#         $('#sh-pos-abs').toggle( function(){
#                 $('.sh-header').addClass('clicked');
#                 $('.hd-sh-wrapper').removeClass('nkoout').addClass('nkoin').show();
#             }, function(){
#                 $('.hd-sh-wrapper').removeClass('nkoin').addClass('nkoout');
#
#                 $('.main-sh').removeClass('clicked');
#                 if( $('#hidden-url').is(":visible") ) {
#                     $('#copy-to-clip').click();
#                 }
#         });
#
#         //var pathname = 'https://www.filmaffinity.com' + location.pathname + location.search;
#         var pathname = encodeURI('https://www.filmaffinity.com/es/topcat.php?id=new_th_es');
#         var slideOptions = { direction: 'left' };
#
#         $('#copy-to-clip').toggle(
#             function(){
#                 $('#hidden-url').show();
#
#                     $('#hidden-url').find(':input').val(pathname);
#                     //$('#hidden-url').find(':input').select();
#                     var text = $('#hidden-url').find(':input').text();
#             },
#             function(){
#                     $('#hidden-url').hide();
#         });
#
#         $('#hidden-url').on('click', '#copy-clipboard', function(){
#             $(this).text( $('#copy-clipboard').attr('data-text') );
#             navigator.clipboard.writeText( pathname )
#                 .then(() => {
#                     console.log( pathname );
#             }).catch(err => {
#                     console.error('Could not copy text: ', err);
#             });
#         })
#
#         $('#hidden-url').find('.hide-url').click(function()
#         {
#             $('#copy-to-clip').trigger('click')
#         });
#
#         hideOnClick();
#     });
# </script>
# <div class="hd-sh-main-wrapper">
# <div class="hd-sh-wrapper">
# <a href="#" id="copy-to-clip" title="Copia la URL para compartir">
# <div class="share-icon" id="copy-to-clip-container"><i class="fas fa-link"></i></div>
# </a>
# <a class="fb-sh" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopcat.php%3Fid%3Dnew_th_es&amp;t=Cartelera España" target="_BLANK" title="Comparte en Facebook">
# <div class="share-icon"><i class="fab fa-facebook-f"></i></div>
# </a>
# <a class="tw-sh" href="https://twitter.com/intent/tweet?text=Cartelera%20Espa%C3%B1a en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopcat.php%3Fid%3Dnew_th_es" target="_BLANK" title="Comparte en Twitter">
# <div class="share-icon"><i class="fab fa-twitter"></i></div>
# </a>
# <a class="wh-sh" href="https://api.whatsapp.com/send?text=Cartelera%20Espa%C3%B1a en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ftopcat.php%3Fid%3Dnew_th_es" target="_BLANK" title="Comparte en WhatsApp">
# <div class="share-icon"><i class="fab fa-whatsapp"></i></div>
# </a>
# </div>
# </div>
# <div id="hidden-url">
# <input size="55" type="text"/><i class="fas fa-times-circle hide-url"></i>
# <div data-text="Copiado" id="copy-clipboard">Haz click aquí para copiar la URL</div>
# </div>
# <div class="cat-header">
# <h1 id="main-title">
#         Cartelera España    </h1>
# </div>
# <style>
# .cat-nl-top2 { margin-top: 5px;}
# .cat-nl-top2 .f-right{ float: right;}
# .cat-nl-top2 .np-cat{font-size: 10px; border-radius: 6px; display: inline-block; padding: 5px; border: 1px solid #e2e2e2; box-shadow: 0 1px 5px #e2e2e2; background-color: #557CAD;}
# .cat-nl-top2 a .np-cat{ color: #FFF; }
# .cat-nl-top2 .np-cat i{ color: #FFF; vertical-align: text-top; margin-left: 4px; margin-right: 4px;}
# .cat-nl-top2 .np-cat:hover{ background: #F0F0F0; color: #333; }
# .cat-nl-top2 a:hover .np-cat{ color: #333;}
# .cat-nl-top2 .np-cat:hover i{ color: #333; margin-left: 4px; margin-right: 4px;}
# </style>
# <script>
# $(function()
# {
#     $('body').on('click', '.youtube', function(event){
#
#         event.preventDefault();
#
#         var movieId = $(this).closest('.movie-card').attr('data-movie-id');
#
#         $.colorbox({title: '<a href="'+ pageUrl('evideos.php?movie_id=' + movieId) + '">Ver más resultados</a>', html: $(this).attr('data-code') });
#
#         $('#cboxOverlay').bind('click', function(e){
#             e.stopImmediatePropagation();
#             e.preventDefault();
#             e.stopPropagation();
#             $.colorbox.close();
#           return false;
#         });
#     })
# });
# </script>
# <div class="margin-ntabs">
# <ul class="ntabs">
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Vista general</a></li><li class="active"><a href="https://www.filmaffinity.com/es/topcat.php?id=new_th_es">Valoración</a></li><li><a href="https://www.filmaffinity.com/es/countcat.php?id=new_th_es">Popularidad</a></li><li><a href="https://www.filmaffinity.com/es/catbygenre.php?id=new_th_es">Género</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=new_th_es">Fecha de lanzamiento</a></li><li><a href="https://www.filmaffinity.com/es/reccat.php?cat=new_th_es">Votaciones almas gemelas</a></li> </ul>
# <div class="cat-nl-top2">
# <div class="f-right">
# <div class="cat-nl">
# <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">
# <span class="np-cat"><i class="fal fa-calendar"></i> <span>Próximos estrenos España <i class="fal fa-angle-double-right"></i></span></span>
# </a>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="cat-list">
# <div id="wrapper-cat">
# <div class="top-movie first">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="491812">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home "><img alt="Spider-Man: No Way Home " height="149" src="https://pics.filmaffinity.com/spider_man_no_way_home-642739124-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 148 min.            </div>
# <div class="pos">1</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home ">Spider-Man: No Way Home </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=FAN&amp;attr=rat_count&amp;nodoc" title="Fantástico">Fantástico</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/

# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film571166.html" title="Licorice Pizza "><img alt="Licorice Pizza " height="145" src="https://pics.filmaffinity.com/licorice_pizza-862632135-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 133 min.            </div>
# <div class="pos">5</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film571166.html" title="Licorice Pizza ">Licorice Pizza </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=CO&amp;attr=rat_count&amp;nodoc" title="Comedia">Comedia</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film571166.html" title="See all">Es la historia de Alana Kane y Gary Valentine, de cómo se conocen, pasan el tiempo juntos y acaban enamorándose en el Valle de San Fernando en 1973.<br/>
# <br/>
# </a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Paul%20Thomas%20Anderson" title="Paul Thomas Anderson">Paul Thomas Anderson</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Alana%20Haim" title="Alana Haim">Alana Haim</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Cooper%20Hoffman" title="Cooper Hoffman">Cooper Hoffman</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Sean%20Penn" title="Sean Penn">Sean Penn</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x855b3f?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=571166"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">145</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">7,3</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>2.557                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">viernes, 11 de febrero</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div style="margin: 0 15px;">
# <div id="smartIntxt">
# <script type="text/javascript">
#       var s = 'filmaffinity';
#       var r = 'es';
#       var e = 'smartIntxt';
#       var c = '';
#       var p = '109361';
#       var t = 'https://des.smartclip.net/ads?type=dyn&sz=400x320&plc='+p+'&sc_sitName='+s+'&sc_cc='+r+'&elementId='+e+'&cat='+c;
#       t+='&ref='+encodeURIComponent(window.top.document.URL);t+='&rnd='+Math.round(Math.random()*1e8);
#       var s=document.createElement('script');s.type='text/javascript';s.src=t;document.body.appendChild(s);
#     </script>
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="375190">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film375190.html" title="Maixabel "><img alt="Maixabel " height="143" src="https://pics.filmaffinity.com/maixabel-491379276-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 115 min.            </div>
# <div class="pos">6</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film375190.html" title="Maixabel ">Maixabel </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="España" class="nflag" src="/imgs/countries2/ES.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=DR&amp;attr=rat_count&amp;nodoc" title="Drama">Drama</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film375190.html" title="See all">Maixabel Lasa pierde en el año 2000 a su marido, Juan María Jaúregui, asesinado por ETA. Once años más tarde, recibe una petición insólita: uno de los asesinos ha pedido entrevistarse con ella en la ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film375190.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Ic%C3%ADar%20Bolla%C3%ADn" title="Icíar Bollaín">Icíar Bollaín</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Blanca%20Portillo" title="Blanca Portillo">Blanca Portillo</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Luis%20Tosar" title="Luis Tosar">Luis Tosar</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Urko%20Olazabal" title="Urko Olazabal">Urko Olazabal</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x8325dz?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=375190"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">62</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">7,3</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>7.649                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">24 de septiembre de 2021</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="658785">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film658785.html" title="El amor en su lugar "><img alt="El amor en su lugar " height="144" src="https://pics.filmaffinity.com/love_gets_a_room-691227652-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 103 min.            </div>
# <div class="pos">7</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film658785.html" title="El amor en su lugar ">El amor en su lugar </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="España" class="nflag" src="/imgs/countries2/ES.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=DR&amp;attr=rat_count&amp;nodoc" title="Drama">Drama</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film658785.html" title="See all">Enero de 1942, 400.000 judíos de toda Polonia llevan más de un año confinados por los nazis en un estrecho gueto en mitad de la ciudad. Fuera del muro, la vida sigue adelante. Dentro, sus habitantes ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film658785.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Rodrigo%20Cort%C3%A9s" title="Rodrigo Cortés">Rodrigo Cortés</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Clara%20Rugaard" title="Clara Rugaard">Clara Rugaard</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Ferdia%20Walsh-Peelo" title="Ferdia Walsh-Peelo">Ferdia Walsh-Peelo</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Magnus%20Krepper" title="Magnus Krepper">Magnus Krepper</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x85gv0i?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=658785"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">5</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">7,2</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>1.379                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">3 de diciembre de 2021</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="454387">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film454387.html" title="No somos nada "><img alt="No somos nada " height="149" src="https://pics.filmaffinity.com/no_somos_nada-691633827-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 100 min.            </div>
# <div class="pos">8</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film454387.html" title="No somos nada ">No somos nada </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="España" class="nflag" src="/imgs/countries2/ES.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=DO&amp;attr=rat_count&amp;nodoc" title="Documental">Documental</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film454387.html" title="See all">La Polla Records, una de las bandas más legendarias del punk, regresa para decir adiós. Con motivo de la gira definitiva del grupo, su vocalista, Evaristo Páramos, revive 40 años de historia desde ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film454387.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Javier%20Corcuera" title="Javier Corcuera">Javier Corcuera</a></span></div> </div>
# <div class="cast">
# <div class="credits"><i> intervenciones de:</i> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Evaristo%20P%C3%A1ramos" title="Evaristo Páramos">Evaristo Páramos</a></span></div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x844qnm?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=454387"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">5</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">7,1</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>199                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">28 de enero de 2022</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="555900">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film555900.html" title="Libertad "><img alt="Libertad " height="142" src="https://pics.filmaffinity.com/libertad-822762849-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 104 min.            </div>
# <div class="pos">9</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film555900.html" title="Libertad ">Libertad </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="España" class="nflag" src="/imgs/countries2/ES.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=DR&amp;attr=rat_count&amp;nodoc" title="Drama">Drama</a>
# ...
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Leire%20Apellaniz" title="Leire Apellaniz">Leire Apellaniz</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Marc%20Sempere%20Moya" title="Marc Sempere Moya">Marc Sempere Moya</a></span></div> </div>
# <div class="cast">
# <div class="credits"><i> intervenciones de:</i> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=El%20Ni%C3%B1o%20de%20Elche" title="El Niño de Elche">El Niño de Elche</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Paqui%20Molina" title="Paqui Molina">Paqui Molina</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Aladino%20Contreras" title="Aladino Contreras">Aladino Contreras</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x872u5h?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=158517"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">4</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">6,0</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>56                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">viernes, 4 de febrero</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="112313">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film112313.html" title="The King's Man: La primera misión "><img alt="The King's Man: La primera misión " height="149" src="https://pics.filmaffinity.com/the_king_s_man-412831292-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 131 min.            </div>
# <div class="pos">37</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film112313.html" title="The King's Man: La primera misión ">The King's Man: La primera misión </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=TH&amp;attr=rat_count&amp;nodoc" title="Thriller">Thriller</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film112313.html" title="See all">Cuando un grupo formado por los tiranos y las mentes criminales más malvadas de la historia se une para desencadenar una guerra que matará a millones de personas, un hombre tendrá que luchar a ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film112313.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Matthew%20Vaughn" title="Matthew Vaughn">Matthew Vaughn</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Ralph%20Fiennes" title="Ralph Fiennes">Ralph Fiennes</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Harris%20Dickinson" title="Harris Dickinson">Harris Dickinson</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Djimon%20Hounsou" title="Djimon Hounsou">Djimon Hounsou</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x86ebli?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=112313"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">22</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">5,9</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>2.367                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">29 de diciembre de 2021</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="215095">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film215095.html" title="One Shot (Misión de rescate) "><img alt="One Shot (Misión de rescate) " height="150" src="https://pics.filmaffinity.com/one_shot-937319731-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 97 min.            </div>
# <div class="pos">38</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film215095.html" title="One Shot (Misión de rescate) ">One Shot (Misión de rescate) </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=AC&amp;attr=rat_count&amp;nodoc" title="Acción">Acción</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film215095.html" title="See all">Los miembros de un escuadrón de élite de los Navy SEAL, en una misión encubierta para transportar a un importante prisionero desde una prisión secreta de la CIA, quedan atrapados cuando un grupo de ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film215095.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=James%20Nunn" title="James Nunn">James Nunn</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Scott%20Adkins" title="Scott Adkins">Scott Adkins</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Ashley%20Greene" title="Ashley Greene">Ashley Greene</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Ryan%20Phillippe" title="Ryan Phillippe">Ryan Phillippe</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x86v4xj?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=215095"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">1</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">5,8</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>135                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">21 de enero de 2022</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="889123">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film889123.html" title="Los ojos de Tammy Faye "><img alt="Los ojos de Tammy Faye " height="149" src="https://pics.filmaffinity.com/the_eyes_of_tammy_faye-312160260-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 126 min.            </div>
# <div class="pos">39</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film889123.html" title="Los ojos de Tammy Faye ">Los ojos de Tammy Faye </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=DR&amp;attr=rat_count&amp;nodoc" title="Drama">Drama</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film889123.html" title="See all">Biopic del extraordinario ascenso, caída y redención de la telepredicadora evangelista Tammy Faye Bakker. En los años 70 y 80, Tammy Faye y su marido, Jim Bakker, pusieron en pie prácticamente de la ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film889123.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Michael%20Showalter" title="Michael Showalter">Michael Showalter</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Jessica%20Chastain" title="Jessica Chastain">Jessica Chastain</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Andrew%20Garfield" title="Andrew Garfield">Andrew Garfield</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Vincent%20D%27Onofrio" title="Vincent D'Onofrio">Vincent D'Onofrio</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x86ebbq?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=889123"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">41</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">5,8</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>691                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">viernes, 4 de febrero</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# <div class="top-movie">
# <div class="movie-card mc-flex movie-card-22" data-movie-id="967255">
# <div class="mc-left">
# <div class="mc-poster">
# <a href="https://www.filmaffinity.com/es/film967255.html" title="Mamá o papá "><img alt="Mamá o papá " height="144" src="https://pics.filmaffinity.com/mama_o_papa-992780613-msmall.jpg" width="100"/></a>
# </div>
# <div class="duration">
# <i class="far fa-clock"></i> 103 min.            </div>
# <div class="pos">40</div>
# </div>
# <div class="mc-right">
# <h3><a href="https://www.filmaffinity.com/es/film967255.html" title="Mamá o papá ">Mamá o papá </a></h3>
# <div class="mc-right-content">
# <div class="mc-data">
# <div>2021 <img alt="España" class="nflag" src="/imgs/countries2/ES.png"/></div>
# <div class="synop">
# <a class="genre" href="https://www.filmaffinity.com/es/moviegenre.php?genre=CO&amp;attr=rat_count&amp;nodoc" title="Comedia">Comedia</a>
# <a class="synop-text" href="https://www.filmaffinity.com/es/film967255.html" title="See all">Flora y Víctor son los padres que todo niño querría tener: modernos, divertidos y cariñosos. Sin embargo, todo se tuerce el día que deciden divorciarse y aparece la oportunidad laboral con la que ... <span id="link-full-sinop"><a href="https://www.filmaffinity.com/es/film967255.html">[+]</a></span></a>
# </div>
# <div class="director">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Dani%20de%20la%20Orden" title="Dani de la Orden">Dani de la Orden</a></span></div> </div>
# <div class="cast">
# <div class="credits"><span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Paco%20Le%C3%B3n" title="Paco León">Paco León</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Miren%20Ibarguren" title="Miren Ibarguren">Miren Ibarguren</a>,</span> <span class="nb"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Laura%20Quir%C3%B3s" title="Laura Quirós">Laura Quirós</a></span> ...</div> </div>
# </div>
# <div class="mc-actions">
# <a class="mc-action youtube" data-code='&lt;iframe frameborder="0" width="1280" height="720" allowfullscreen src="https://www.dailymotion.com/embed/video/x86asxa?queue-enable=false&amp;amp;autoplay=true"&gt;&lt;/iframe&gt;' href=""><i class="fab fa-youtube"></i> Trailer</a>
# <a class="mc-action" href="https://www.filmaffinity.com/es/cityTheaters.php?movie_id=967255"><i class="fas fa-ticket-alt"></i> Cines <span class="badge">103</span></a>
# </div>
# <div class="stats">
# <div class="avg-rating">5,5</div>
# <div class="rat-count">
# <div><i class="fa fa-simple-user-o-fa"></i></div>1.701                        </div>
# </div>
# </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <div class="cat-info">
# <div class="cat-info-data">
# <div>
#                         desde: <span class="date">17 de diciembre de 2021</span><span class="time"></span>
# </div>
# </div><!-- cat-info-data -->
# </div>
# </div>
# </div>
# </div>
# <div class="np-cat-wrapper">
# <div class="cat-nl">
# <a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">
# <span class="np-cat"><i class="fal fa-calendar"></i> <span>Próximos estrenos España <i class="fal fa-angle-double-right"></i></span></span>
# </a>
# </div>
# </div>
# <div class="cat-disclaimer">
#     Si sabes de alguna película | serie que crees que debería estar | no estar en esta categoría por favor avísanos por <a href="https://www.filmaffinity.com/es/imsendmsg.php?to=985462">mensaje</a>, DM en <a href="https://twitter.com/Filmaffinity" target="_blank">Twitter</a> o email: info@filmaffinity.com indicando categoría y el país de la misma. Gracias.</div>
# </div>
# <div style="padding-top: 50px; clear: both;"><div>
# </div></div></td>
# </tr>
# </table>
# </div>
# <div id="bpanel">
# <div style="text-align:center; padding: 10px">
# <a href="https://www.filmaffinity.com/es/faq.php">Preguntas más frecuentes</a>
#     | <a href="https://www.filmaffinity.com/es/private.php">Política de privacidad / condiciones de uso</a>
#     | <a href="#" id="privacy-config-2">Configuración de privacidad</a>
#     | <a href="https://m.filmaffinity.com/es/topcat.php?id=new_th_es"><strong>Ir a Versión MÓVIL</strong></a>
# </div>
# <div style="text-align:center; padding: 10px 2px">
# <span class="subtext">© 2002-2022 Filmaffinity - Movieaffinity | Filmaffinity es una página de recomendación de películas y series, y es un medio totalmente independiente cuya principal prioridad es la privacidad y seguridad de los datos de sus usuarios.<br/>All Rights Reserved - Todos los derechos reservados</span>
# </div>
# </div>
# </body>

# %%
# Esto retorna un objeto bs4
soup.title
# Out:
# <title>Cartelera España - FilmAffinity</title>

# %%
# Con .text lo convertimos a str

soup.title.text
# Out:
# 'Cartelera España - FilmAffinity'

# %% [markdown]
# ### Filtros con bs4

# %%
# Encontrar la primera etiqueta h1

soup.find("h1")
# Out:
# <h1 id="main-title">
#         Cartelera España    </h1>

# %%
# Con .find_all() encontramos todas las etiquetas y nos retorna una lista con objetos bs4

soup.find_all("h1")
# Out:
# [<h1 id="main-title">
#          Cartelera España    </h1>]

# %%
# Encuentra la primera etiqueta h3

soup.find("h3")
# Out:
# <h3><a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home ">Spider-Man: No Way Home </a></h3>

# %%
# Encuentra todas las etiquetas h3

soup.find_all("h3")
# Out:
# [<h3><a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home ">Spider-Man: No Way Home </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film281888.html" title="Drive My Car ">Drive My Car </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film925403.html" title="El buen patrón ">El buen patrón </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film776481.html" title="West Side Story ">West Side Story </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film571166.html" title="Licorice Pizza ">Licorice Pizza </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film375190.html" title="Maixabel ">Maixabel </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film658785.html" title="El amor en su lugar ">El amor en su lugar </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film454387.html" title="No somos nada ">No somos nada </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film555900.html" title="Libertad ">Libertad </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film465767.html" title="Seis días corrientes ">Seis días corrientes </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film407458.html" title="Belfast ">Belfast </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film963718.html" title="Un amor intranquilo ">Un amor intranquilo </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film822006.html" title="¡Canta! 2 ">¡Canta! 2 </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film691628.html" title="La cordillera de los sueños ">La cordillera de los sueños </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film767738.html" title="La tragedia de Macbeth ">La tragedia de Macbeth </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film580527.html" title="El método Williams ">El método Williams </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film115715.html" title="En un muelle de Normandía ">En un muelle de Normandía </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film975136.html" title="La vida era eso ">La vida era eso </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film468660.html" title="Delicioso ">Delicioso </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film880572.html" title="El callejón de las almas perdidas ">El callejón de las almas perdidas </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film405972.html" title="El contador de cartas ">El contador de cartas </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film596523.html" title="Todo ha ido bien ">Todo ha ido bien </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film184929.html" title="Buscando a la mágica Doremi ">Buscando a la mágica Doremi </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film315057.html" title="El poder del perro ">El poder del perro </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film577324.html" title="100 días con la Tata ">100 días con la Tata </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film738775.html" title="Scream ">Scream </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film622126.html" title="La casa Gucci ">La casa Gucci </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film799681.html" title="Encanto ">Encanto </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film757813.html" title="Cazafantasmas: Más allá ">Cazafantasmas: Más allá </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film198721.html" title="El caso Villa Caprice ">El caso Villa Caprice </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film931173.html" title="El brindis ">El brindis </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film453220.html" title="La abuela ">La abuela </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film948651.html" title="El pacto ">El pacto </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film242779.html" title="Madres paralelas ">Madres paralelas </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film748908.html" title="Uncharted ">Uncharted </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film158517.html" title="Canto cósmico. Niño de Elche ">Canto cósmico. Niño de Elche </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film112313.html" title="The King's Man: La primera misión ">The King's Man: La primera misión </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film215095.html" title="One Shot (Misión de rescate) ">One Shot (Misión de rescate) </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film889123.html" title="Los ojos de Tammy Faye ">Los ojos de Tammy Faye </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film967255.html" title="Mamá o papá ">Mamá o papá </a></h3>]

# %%
len(soup.find_all("h3"))
# Out:
# 40

# %%
# Podemos encadenar filtros siempre que nos retorne un objeto bs4

soup.find("h3").find("a")
# Out:
# <a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home ">Spider-Man: No Way Home </a>

# %%
soup.find("h3").find("a")["href"]
# Out:
# 'https://www.filmaffinity.com/es/film491812.html'

# %% [markdown]
# Cuando veamos una etiqueta con **class** en ella, podemos usarla para hacer un filtro más específico.
# ```html
# <div class="duration">
# ```
#
# Como en python **`class`** es una palabra reservada, debemos usar **`class_`**.

# %%
soup.find("div", class_ = "duration")
# Out:
# <div class="duration">
# <i class="far fa-clock"></i> 148 min.            </div>

# %%
soup.find_all("div", class_ = "duration")
# Out:
# [<div class="duration">
#  <i class="far fa-clock"></i> 148 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 179 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 120 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 156 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 133 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 115 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 103 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 100 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 104 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 85 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 98 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 118 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 110 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 84 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 105 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 138 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 106 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 109 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 112 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 150 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 112 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 112 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 92 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 128 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 82 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 114 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 157 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 99 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 124 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 103 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 87 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 99 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 115 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 123 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 115 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 93 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 131 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 97 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 126 min.            </div>,
#  <div class="duration">
#  <i class="far fa-clock"></i> 103 min.            </div>]

# %%
soup.find("div", class_ = "avg-rating")
# Out:
# <div class="avg-rating">7,4</div>

# %%
soup.find_all("div", class_ = "avg-rating")
# Out:
# [<div class="avg-rating">7,4</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,2</div>,
#  <div class="avg-rating">7,1</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">6,9</div>,
#  <div class="avg-rating">6,8</div>,
#  <div class="avg-rating">6,8</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,4</div>,
#  <div class="avg-rating">6,4</div>,
#  <div class="avg-rating">6,3</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,1</div>,
#  <div class="avg-rating">6,1</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">5,9</div>,
#  <div class="avg-rating">5,8</div>,
#  <div class="avg-rating">5,8</div>,
#  <div class="avg-rating">5,5</div>]

# %% [markdown]
# Otra forma de usar estos filtros de **`bs4`** es atraves del parametro **`attrs`** de un diccionario.
#
# Este diccionario tendrá como llave el nombre de las etiquetas y como valor el valor asociado a esa etiqueta:

# %%
dicc_bs4 = {"class" : "avg-rating"}

soup.find("div", attrs = dicc_bs4)
# Out:
# <div class="avg-rating">7,4</div>

# %%
soup.find("div", attrs = dicc_bs4).text
# Out:
# '7,4'

# %%
dicc_bs4 = {"class" : "avg-rating"}

soup.find_all("div", attrs = dicc_bs4)
# Out:
# [<div class="avg-rating">7,4</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,3</div>,
#  <div class="avg-rating">7,2</div>,
#  <div class="avg-rating">7,1</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">7,0</div>,
#  <div class="avg-rating">6,9</div>,
#  <div class="avg-rating">6,8</div>,
#  <div class="avg-rating">6,8</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,7</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,6</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,5</div>,
#  <div class="avg-rating">6,4</div>,
#  <div class="avg-rating">6,4</div>,
#  <div class="avg-rating">6,3</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,2</div>,
#  <div class="avg-rating">6,1</div>,
#  <div class="avg-rating">6,1</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">6,0</div>,
#  <div class="avg-rating">5,9</div>,
#  <div class="avg-rating">5,8</div>,
#  <div class="avg-rating">5,8</div>,
#  <div class="avg-rating">5,5</div>]

# %% [markdown]
# Utilizando bucles podemos iterar sobre los **`.find_all()`** y sacar información de forma automatizada.

# %%
# En la etiqueta h3 tenemos el url y el titulo de la pelicual

soup.find_all("h3")
# Out:
# [<h3><a href="https://www.filmaffinity.com/es/film491812.html" title="Spider-Man: No Way Home ">Spider-Man: No Way Home </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film281888.html" title="Drive My Car ">Drive My Car </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film925403.html" title="El buen patrón ">El buen patrón </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film776481.html" title="West Side Story ">West Side Story </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film571166.html" title="Licorice Pizza ">Licorice Pizza </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film375190.html" title="Maixabel ">Maixabel </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film658785.html" title="El amor en su lugar ">El amor en su lugar </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film454387.html" title="No somos nada ">No somos nada </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film555900.html" title="Libertad ">Libertad </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film465767.html" title="Seis días corrientes ">Seis días corrientes </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film407458.html" title="Belfast ">Belfast </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film963718.html" title="Un amor intranquilo ">Un amor intranquilo </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film822006.html" title="¡Canta! 2 ">¡Canta! 2 </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film691628.html" title="La cordillera de los sueños ">La cordillera de los sueños </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film767738.html" title="La tragedia de Macbeth ">La tragedia de Macbeth </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film580527.html" title="El método Williams ">El método Williams </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film115715.html" title="En un muelle de Normandía ">En un muelle de Normandía </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film975136.html" title="La vida era eso ">La vida era eso </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film468660.html" title="Delicioso ">Delicioso </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film880572.html" title="El callejón de las almas perdidas ">El callejón de las almas perdidas </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film405972.html" title="El contador de cartas ">El contador de cartas </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film596523.html" title="Todo ha ido bien ">Todo ha ido bien </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film184929.html" title="Buscando a la mágica Doremi ">Buscando a la mágica Doremi </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film315057.html" title="El poder del perro ">El poder del perro </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film577324.html" title="100 días con la Tata ">100 días con la Tata </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film738775.html" title="Scream ">Scream </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/film622126.html" title="La casa Gucci ">La casa Gucci </a></h3>,
#  <h3><a href="https://www.filmaffinity.com/es/
# 27  https://www.filmaffinity.com/es/film799681.html
# 28  https://www.filmaffinity.com/es/film757813.html
# 29  https://www.filmaffinity.com/es/film198721.html
# 30  https://www.filmaffinity.com/es/film931173.html
# 31  https://www.filmaffinity.com/es/film453220.html
# 32  https://www.filmaffinity.com/es/film948651.html
# 33  https://www.filmaffinity.com/es/film242779.html
# 34  https://www.filmaffinity.com/es/film748908.html
# 35  https://www.filmaffinity.com/es/film158517.html
# 36  https://www.filmaffinity.com/es/film112313.html
# 37  https://www.filmaffinity.com/es/film215095.html
# 38  https://www.filmaffinity.com/es/film889123.html
# 39  https://www.filmaffinity.com/es/film967255.html

# %%
# path_or_buf = Nombre del archivo terminado en .csv
# index = False para que no se guarde el indice como nueva columna en el csv
# sep = "," para que el separador sea ",", se puede cambiar por cualquier otro separador.

df.to_csv(path_or_buf = "filmaffinity.csv", index = False, sep = ",")

# %% [markdown]
# ### Agregar al DataFrame la duración de cada pelicula y su puntaje:

# %% [markdown]
# ### Información de 1 pelicula:
#
# Vamos a entrar al primer **`url`** y sacar toda su información.

# %%
url = "https://www.filmaffinity.com/es/film491812.html"

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <title>Spider-Man: No Way Home  (2021) - FilmAffinity</title>
# <meta charset="utf-8"/>
# <meta content="Spider-Man: No Way Home es una película dirigida por Jon Watts con Tom Holland, Zendaya, Benedict Cumberbatch, Alfred Molina .... Año: 2021. Título original: Spider-Man: No Way Home. Sinopsis: Por primera vez en la historia cinematográfica de Spider-Man, nuestro héroe, vecino y amigo es desenmascarado, y por tanto, ya no es capaz de separar su vida normal de los enormes riesgos que conlleva ..." name="description"/>
# <meta content="FilmAffinity" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="video.movie" property="og:type"/>
# <meta name="twitter:site" value="@Filmaffinity"/>
# <meta content="https://www.filmaffinity.com/es/film491812.html" property="og:url">
# <meta content="Spider-Man: No Way Home  (2021)" property="og:title">
# <meta content="Género: Fantástico | Sinopsis: Por primera vez en la historia cinematográfica de Spider-Man, nuestro héroe, vecino y amigo es desenmascarado, y por tanto, ya no es capaz de separar su vida normal de los enormes riesgos que conlleva ..." property="og:description">
# <meta content="https://pics.filmaffinity.com/spider_man_no_way_home-642739124-mmed.jpg" property="og:image">
# <link href="http://www.filmaffinity.com/es/film491812.html" rel="canonical"/>
# <link href="https://m.filmaffinity.com/es/movie.php?id=491812" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="/favicon.png" rel="icon" type="image/png"/>
# <link href="/style/film.1641295547.css" rel="stylesheet" type="text/css"/>
# <link href="/style/share.1539096291.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/fa-ui-theme/jquery-ui.min.1539096306.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/fa-ui-theme/jquery-ui.structure.min.1539096306.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/fa-ui-theme/jquery-ui.theme.min.1539096306.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/colorbox/colorbox-1.6.1539096305.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/colorbox/colorbox-fa.1539096305.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/jqvmap/jqvmap.min.1561450861.css" rel="stylesheet" type="text/css"/>
# <link href="/style/main3.1644579350.css" rel="stylesheet" type="text/css"/>
# <link href="/style/moviecards3.1644922099.css" rel="stylesheet" type="text/css"/>
# <link href="/style/fa-awesome.1539096291.css" rel="stylesheet" type="text/css"/>
# <link href="/style/font-awesome.5.11.1.min.1579174691.css" rel="stylesheet" type="text/css"/>
# <link href="/style/fa-icons.1582288477.css" rel="stylesheet" type="text/css"/>
# <link href="/style/magic-check.min.1539096291.css" rel="stylesheet" type="text/css"/>
# <link href="/style/rating2.1634296683.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/autocomplete/easy-autocomplete.min.1585727670.css" rel="stylesheet" type="text/css"/>
# <link href="/style/jquery/autocomplete/easy-autocomplete.themes.min.1585727670.css" rel="stylesheet" type="text/css"/>
# <script src="/js/local_es.1539096293.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-3.1.0.min.1539096302.js" type="text/javascript"></script>
# <script src="/js/jquery/jquery-migrate-1.4.1.min.1539096302.js" type="text/javascript"></script>
# <script src="/js/jquery/ui/jquery-ui-1.12.1.min.1539096308.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/jquery.colorbox-1.6.1539096308.js" type="text/javascript"></script>
# <script src="/js/foto.1635495347.js" type="text/javascript"></script>
# <script src="/js/crc32.1539096293.js" type="text/javascript"></script>
# <script src="/js/translate-context.1539096293.js" type="text/javascript"></script>
# <script src="/js/locale/friends-texts-es_ES.1558012521.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/jquery.cookie.1539096308.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/rating-bars.1539096309.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/chartjs/chart.min.1568363825.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/jqvmap/jquery.vmap.min.1561450834.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/jqvmap/jquery.vmap.world.1561450836.js" type="text/javascript"></script>
# <script src="/js/locale/texts-es_ES.1643123251.js" type="text/javascript"></script>
# <script src="/js/ads.1539096293.js" type="text/javascript"></script>
# <script src="/js/main.1644579650.js" type="text/javascript"></script>
# <script src="/js/pagetop.1621520988.js" type="text/javascript"></script>
# <script src="/js/z-index-fix.1539096292.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/lazysizes/lazysizes.min.1602068375.js" type="text/javascript"></script>
# <script src="/js/fa-lists-tip.1539096292.js" type="text/javascript"></script>
# <script src="/js/fa_rating2.1539096293.js" type="text/javascript"></script>
# <script src="/js/hide-qt.1584456412.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/autocomplete/jquery.easy-autocomplete.1643901885.js" type="text/javascript"></script>
# <script src="/js/jquery/plugin/autocomplete/fa-autocomplete.1602676109.js" type="text/javascript"></script>
# <link href="https://www.filmaffinity.com/es/film491812.html" hreflang="es" rel="alternate"/>
# <link href="https://www.filmaffinity.com/en/film491812.html" hreflang="en" rel="alternate"/>
# <link href="https://www.filmaffinity.com/mx/film491812.html" hreflang="es-MX" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ar/film491812.html" hreflang="es-AR" rel="alternate"/>
# <link href="https://www.filmaffinity.com/cl/film491812.html" hreflang="es-CL" rel="alternate"/>
# <link href="https://www.filmaffinity.com/co/film491812.html" hreflang="es-CO" rel="alternate"/>
# <link href="https://www.filmaffinity.com/uy/film491812.html" hreflang="es-UY" rel="alternate"/>
# <link href="https://www.filmaffinity.com/py/film491812.html" hreflang="es-PY" rel="alternate"/>
# <link href="https://www.filmaffinity.com/pe/film491812.html" hreflang="es-PE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ec/film491812.html" hreflang="es-EC" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ve/film491812.html" hreflang="es-VE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/cr/film491812.html" hreflang="es-CR" rel="alternate"/>
# <link href="https://www.filmaffinity.com/hn/film491812.html" hreflang="" rel="alternate"/>
# <link href="https://www.filmaffinity.com/gt/film491812.html" hreflang="es-GT" rel="alternate"/>
# <link href="https://www.filmaffinity.com/bo/film491812.html" hreflang="es-BO" rel="alternate"/>
# <link href="https://www.filmaffinity.com/us/film491812.html" hreflang="en-US" rel="alternate"/>
# <link href="https://www.filmaffinity.com/uk/film491812.html" hreflang="en-GB" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ie/film491812.html" hreflang="en-IE" rel="alternate"/>
# <link href="https://www.filmaffinity.com/au/film491812.html" hreflang="en-AU" rel="alternate"/>
# <link href="https://www.filmaffinity.com/ca/film491812.html" hreflang="en-CA" rel="alternate"/>
# <!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script async="true" type="text/javascript">
# (function() {
#   var host = 'filmaffinity.com';
#   var element = document.createElement('script');
#   var firstScript = document.getElementsByTagName('script')[0];
#   var url = 'https://quantcast.mgr.consensu.org'
#     .concat('/choice/', 'LBBrF-bdAtkuF', '/', host, '/choice.js')
#   var uspTries = 0;
#   var uspTriesLimit = 3;
#   element.async = true;
#   element.type = 'text/javascript';
#   element.src = url;
#
#   firstScript.parentNode.insertBefore(element, firstScript);
#
#   function makeStub() {
#     var TCF_LOCATOR_NAME = '__tcfapiLocator';
#     var queue = [];
#     var win = window;
#     var cmpFrame;
#
#     function addFrame() {
#       var doc = win.document;
#       var otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);
#
#       if (!otherCMP) {
#         if (doc.body) {
#           var iframe = doc.createElement('iframe');
#
#           iframe.style.cssText = 'display:none';
#           iframe.name = TCF_LOCATOR_NAME;
#           doc.body.appendChild(iframe);
#         } else {
#           setTimeout(addFrame, 5);
#         }
#       }
#       return !otherCMP;
#     }
#
#     function tcfAPIHandler() {
#       var gdprApplies;
#       var args = arguments;
#
#       if (!args.length) {
#         return queue;
#       } else if (args[0] === 'setGdprApplies') {
#         if (
#           args.length > 3 &&
#           args[2] === 2 &&
#           typeof args[3] === 'boolean'
#         ) {
#           gdprApplies = args[3];
#           if (typeof args[2] === 'function') {
#             args[2]('set', true);
#           }
#         }
#       } else if (args[0] === 'ping') {
#         var retr = {
#           gdprApplies: gdprApplies,
#           cmpLoaded: false,
#           cmpStatus: 'stub'
#         };
#
#         if (typeof args[2] === 'function') {
#           args[2](retr);
#         }
#       } else {
#         queue.push(args);
#       }
#     }
#
#     function postMessageEventHandler(event) {
#       var msgIsString = typeof event.data === 'string';
#       var json = {};
#
#       try {
#         if (msgIsString) {
#           json = JSON.parse(event.data);
#         } else {
#           json = event.data;
#         }
#       } catch (ignore) {}
#
#       var payload = json.__tcfapiCall;
#
#       if (payload) {
#         window.__tcfapi(
#           payload.command,
#           payload.version,
#           function(retValue, success) {
#             var returnMsg = {
#               __tcfapiReturn: {
#                 returnValue: retValue,
#                 success: success,
#                 callId: payload.callId
#               }
#             };
#             if (msgIsString) {
#               returnMsg = JSON.stringify(returnMsg);
#             }
#             if (event && event.source && event.source.postMessage) {
#               event.source.postMessage(returnMsg, '*');
#             }
#           },
#           payload.parameter
#         );
#       }
#     }
#
#     while (win) {
#       try {
#         if (win.frames[TCF_LOCATOR_NAME]) {
#           cmpFrame = win;
#           break;
#         }
#       } catch (ignore) {}
#
#       if (win === window.top) {
#         break;
#       }
#       win = win.parent;
#     }
#     if (!cmpFrame) {
#       addFrame();
#       win.__tcfapi = tcfAPIHandler;
#       win.addEventListener('message', postMessageEventHandler, false);
#     }
#   };
#
#   makeStub();
#
#   var uspStubFunction = function() {
#     var arg = arguments;
#     if (typeof window.__uspapi !== uspStubFunction) {
#       setTimeout(function() {
#         if (typeof window.__uspapi !== 'undefined') {
#           window.__uspapi.apply(window.__uspapi, arg);
#         }
#       }, 500);
#     }
#   };
#
#   var checkIfUspIsReady = function() {
#     uspTries++;
#     if (window.__uspapi === uspStubFunction && uspTries < uspTriesLimit) {
#       console.warn('USP is not accessible');
#     } else {
#       clearInterval(uspInterval);
#     }
#   };
#
#   if (typeof window.__uspapi === 'undefined') {
#     window.__uspapi = uspStubFunction;
#     var uspInterval = setInterval(checkIfUspIsReady, 6000);
#   }
# })();
# </script>
# <!-- End Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->
# <script>
#     $(function(){
#         sessPing("01620cc838acceb16dc8ed8facff6d63d7279ccc13", 2400);
#         var tcTexts = TranslateContext.getInstance(commonTextsJs);
#     });
# </script>
# <script async="async" src="https://sc-devel.s3.eu-central-1.amazonaws.com/sc-tagmanager/sc_gpt_lstapc.js"></script>
# <script>
#
#         var googletag = googletag || {};
#
#         googletag.cmd = googletag.cmd || [];
#
#  </script>
# <script src="https://s3.eu-central-1.amazonaws.com/sc-devel/Skins/SMCService.js"></script>
# <script src="https://s3.eu-central-1.amazonaws.com/sc-devel/sc-tagmanager/filmaffinity.js"></script>
# <script async="async" src="https://cdn.smartclip-services.com/v1/Storage-a482323/smartclip-services/HeaderBidding/js/SmartclipConfig.js"></script>
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "13181121" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#     el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=13181121&amp;cv=2.0&amp;cj=1"/>
# </noscript>
# <script>$(function(){sendpv("f78d96a0d208666722c555978ba4e844");});</script>
# </meta></meta></meta></meta></head>
# <body>
# <script>
#           (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#           ga('create', 'UA-74155504-1', 'auto');
#           ga('send', 'pageview');
#         </script>
# <div id="page-header">
# <div id="header-top">
# <div class="cpanel top-wrapper">
# <div id="logo-container">
# <a href="https://www.filmaffinity.com/es/main.html">
# <img alt="logo" src="/images/logo4.png"/>
# <div class="logo-siteloc">España</div>
# </a>
# </div><!-- logo-container -->
# <div id="topsearch">
# <form accept-charset="UTF-8" action="https://www.filmaffinity.com/es/search.php" method="get">
# <input id="top-search-input" name="stext" size="20" tabindex="1" type="text" value=""/>
# <i class="fas fa-times clear-search"></i>
# <label for="button-search">
# <i class="fas fa-search"></i>
# </label>
# <input id="button-search" type="submit" value=" "/>
# </form>
# <div class="advsearch"><a href="https://www.filmaffinity.com/es/advsearch.php">Búsqueda avanzada <i class="fas fa-angle-double-right"></i></a></div>
# </div><!-- topsearch -->
# <div id="user-login-container">
# <div id="login-register">
# <a class="sign-in" href="https://www.filmaffinity.com/es/login.php"><strong>Iniciar sesión</strong></a> / <a class="register" href="https://www.filmaffinity.com/es/register.php">Registrarse</a>
# </div>
# <div class="user-menu-wr">
# <ul>
# <li>
# <a href="https://www.filmaffinity.com/es/userratings.php?user_id=">
# <span class="ic-w"><i class="fa fa-ratings-fa"></i></span>
#                 Mis Votaciones        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/myreviews.php">
# <span class="ic-w"><i class="fa fa-reviews-fa"></i></span>
#             Críticas        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/mylists.php">
# <span class="ic-w"><i class="fa fa-list"></i></span>
#             Listas <span class="nbr-w">New</span>
# </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/myfriends.php">
# <span class="ic-w"><i class="fa fa fa-friends-fa"></i></span>
#             Amigos / Grupos        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/soulmates.php">
# <span class="ic-w"><i class="fa fa-soulmates-fa"></i></span>
#             Almas gemelas™        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/smsrec.php">
# <span class="ic-w"><i class="fa fa-heart"></i></span>
#                 Recomendaciones        </a>
# </li>
# <li class="user-prof-link">
# <a href="https://www.filmaffinity.com/es/mydata.php">
# <span class="ic-w"><i class="fa fa-address-card-o"></i></span>
#                 Datos personales        </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/user-fav-theaters.php">
# <span class="ic-w"><i class="fa fa-ticket"></i></span>
#                 Cines favoritos            </a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/tours.php">
# <span class="ic-w"><i class="fa fa-ratings-fa"></i></span>
#                 Votar los tours            </a>
# </li>
# <li class="lg-out-li">
# <a class="sign-out" href="#">
#                 Cerrar sesión            </a>
# </li>
# </ul>
# </div>
# </div><!-- user-login -container -->
# </div>
# </div>
# <div id="header-bottom">
# <div class="cpanel news-wrapper">
# <ul id="awardsmenu">
# <li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Últ. críticas</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=TRAILERS">Tráilers</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/rankings.php">Rankings FA <span class="tooltip-new">New</span></a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Nuevo Top FA <span class="tooltip-new">New</span></a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/best_2021.php">2021</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/category.php?id=2022films">2022</a></li><li class="sep">|</li>
# <li><a href="https://www.filmaffinity.com/es/awards.php?award_id=goya&amp;year=2022">Premios Goya 2022</a></li><li class="sep">|</li>
# </ul>
# <div id="trmenu">
# <div class="social-logo" id="fb-top-logo"><a href="http://www.facebook.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Facebook (180.000 followers)"><i class="fab fa-facebook-f"></i></a></div>
# <div class="social-logo" id="tw-top-logo"><a href="http://twitter.com/Filmaffinity" target="_BLANK" title="Sigue a FA en Twitter (60.000 followers)"><i class="fab fa-twitter"></i></a></div>
# <div class="social-logo" id="in-top-logo"><a href="https://www.instagram.com/filmaffinity/" target="_BLANK" title="Sigue a FA en Instagram (155.000 followers)"><i class="fab fa-instagram"></i></a></div>
# </div>
# <div class="version-selector">
# <ul class="version">
# <li class="fixed" data-version="es" title="Cambiar de versión">España <i class="fas fa-chevron-down"></i></li>
# </ul>
# </div>
# <div class="page-versions-pop fa-shadow">
# <div id="vmap" style="width: 630px; height: 400px;"></div>
# <div class="country-names">
# <ul class="continents">
# <li data-continent="america-north">
# <div class="header">Norteamérica <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="us" data-version="us"><img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/> US <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ca" data-version="ca"><img alt="Canadá" class="nflag" src="/imgs/countries2/CA.png"/> Canadá <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="mx" data-version="mx"><img alt="México" class="nflag" src="/imgs/countries2/MX.png"/> México <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="europe">
# <div class="header">Europa <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="es" data-version="es"><img alt="España" class="nflag" src="/imgs/countries2/ES.png"/> España <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gb" data-version="uk"><img alt="Reino Unido" class="nflag" src="/imgs/countries2/GB.png"/> UK <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ie" data-version="ie"><img alt="Irlanda" class="nflag" src="/imgs/countries2/IE.png"/> Irlanda <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# <li data-continent="oceania">
# <div class="header">Oceanía <i class="fas fa-search-plus map-zoom"></i></div>
# <ul class="countries">
# <li data-country-id="au" data-version="au"><img alt="Australia" class="nflag" src="/imgs/countries2/AU.png"/> Australia <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <ul class="continents">
# <li data-continent="america-south">
# <div class="header">América del sur <i class="fas fa-search-plus map-zoom"></i> </div>
# <ul class="countries">
# <li data-country-id="ar" data-version="ar"><img alt="Argentina" class="nflag" src="/imgs/countries2/AR.png"/> Argentina <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cl" data-version="cl"><img alt="Chile" class="nflag" src="/imgs/countries2/CL.png"/> Chile <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="co" data-version="co"><img alt="Colombia" class="nflag" src="/imgs/countries2/CO.png"/> Colombia <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="uy" data-version="uy"><img alt="Uruguay" class="nflag" src="/imgs/countries2/UY.png"/> Uruguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="py" data-version="py"><img alt="Paraguay" class="nflag" src="/imgs/countries2/PY.png"/> Paraguay <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="pe" data-version="pe"><img alt="Perú" class="nflag" src="/imgs/countries2/PE.png"/> Perú <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ec" data-version="ec"><img alt="Ecuador" class="nflag" src="/imgs/countries2/EC.png"/> Ecuador <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="ve" data-version="ve"><img alt="Venezuela" class="nflag" src="/imgs/countries2/VE.png"/> Venezuela <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="cr" data-version="cr"><img alt="Costa Rica" class="nflag" src="/imgs/countries2/CR.png"/> Costa Rica <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="hn" data-version="hn"><img alt="Honduras" class="nflag" src="/imgs/countries2/HN.png"/> Honduras <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="gt" data-version="gt"><img alt="Guatemala" class="nflag" src="/imgs/countries2/GT.png"/> Guatemala <i class="fas fa-arrow-right go-to-version"></i></li>
# <li data-country-id="bo" data-version="bo"><img alt="Bolivia" class="nflag" src="/imgs/countries2/BO.png"/> Bolivia <i class="fas fa-arrow-right go-to-version"></i></li>
# </ul>
# </li>
# </ul>
# <a class="more-info" href="https://www.filmaffinity.com/es/fa-international.php"><i class="fas fa-info-circle"></i> Más información</a>
# </div>
# </div>
# <script type="text/javascript">
#
#     var mapVersions = {"us":"#3C6E99","ca":"#3C6E99","mx":"#3C6E99","es":"#3C6E99","gb":"#3C6E99","ie":"#3C6E99","au":"#3C6E99","ar":"#3C6E99","cl":"#3C6E99","co":"#3C6E99","uy":"#3C6E99","py":"#3C6E99","pe":"#3C6E99","ec":"#3C6E99","ve":"#3C6E99","cr":"#3C6E99","hn":"#3C6E99","gt":"#3C6E99","bo":"#3C6E99"};
#
# /*  //para sacar trazas de coordenadas.
#     jQuery('#vmap').on('drag', function(event)
#     {
#         console.log(jqvmap.transX);
#         console.log(jqvmap.transY);
#         console.log(jqvmap.scale);
#         console.log(jqvmap.zoomCurStep);
#     });
# */
#
#
# </script>
# </div>
# </div>
# </div>
# <div class="cpanel adver-wrapper">
# <div class="adver-fix" id="top-ad">
# <div class="sc-top" id="sc-top">
# <script>
#
#                   googletag.cmd.push(function() {
#
#                         googletag.display('sc-top');
#
#                  });
#
#            </script>
# </div>
# <!-- sc-oop-->
# <div class="sc-oop" id="sc-oop">
# <script>
#
#                  googletag.cmd.push(function() {
#
#                         googletag.display('sc-oop');
#
#                  });
#
#            </script>
# </div>
# </div>
# </div>
# <div id="top-anch">
# <a href="#header-top" title="Ir arriba">
# <img alt="arrow" src="https://www.filmaffinity.com/images/arrow-up2.png"/>
# </a>
# </div>
# <div class="cpanel">
# <table id="main-content-table">
# <tr>
# <td id="mt-left-cell">
# <div id="lsmenu">
# <div class="cat-container">
# <div class="lsmheader">Usuarios</div>
# <ul>
# <li><a class="rate-tours" href="https://www.filmaffinity.com/es/tours.php">Votar los tours</a></li><li><a class="sign-in" href="https://www.filmaffinity.com/es/login.php">Iniciar sesión</a></li><li><a href="https://www.filmaffinity.com/es/register.php">Registrarse</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">España</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Películas en cartelera</a></li><li><a href="https://www.filmaffinity.com/es/cityTheaters.php">Cines España</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_th_es">Próximos estrenos</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_sa_es.html">Estrenos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_sa_es">Próximos Blu-ray venta</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_re_es.html">Ya para alquilar</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_re_es">Próximamente alquiler</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_netflix.html">Netflix</a></li><li><a href="https://www.filmaffinity.com/es/rdcat.php?id=upc_netflix">Netflix (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_movistar_f.html">Movistar + </a></li><li><a href="https://www.filmaffinity.com/es/cat_upc_movistar_f.html">Movistar + (próx)</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_hbo_es.html">HBO Max</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_filmin.html">Filmin</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_rakuten.html">Rakuten TV</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_amazon_es.html">Amazon Prime</a></li><li><a href="https://www.filmaffinity.com/es/cat_disneyplus.html">Disney+</a></li><li><a href="https://www.filmaffinity.com/es/cat_apple_tv_plus.html">Apple TV+</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">USA - UK - FR</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_new_th_us.html">Estrenos USA</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_uk.html">Estrenos Reino Unido</a></li><li><a href="https://www.filmaffinity.com/es/cat_new_th_fr.html">Estrenos Francia</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Rankings FA</div>
# <ul>
# <li style="position: relative;"><strong><a class="Rankings" href="https://www.filmaffinity.com/es/rankings.php">Todos los rankings</a></strong><div id="tooltip-new-menu" style="background: linear-gradient(to bottom, #FFA84C 52%, #FF7B0D 100%) repeat scroll 0 0 rgba(0, 0, 0, 0); border-radius: 5px; color: #FFFFFF; font-size: 11px; line-height: 0.8; padding: 2px 3px; position: absolute; right: 2px; text-shadow: 0.2em 0.2em 0.2em #BBBBBB; bottom: 2px; font-style: italic;"><strong>N</strong></div></li><li><a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fa_movies">El Top 1000 de FA</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Secciones</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/boxoffice.php">Taquilla</a></li><li><a href="https://www.filmaffinity.com/es/trailers.php">Trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestevideos.php">Últimos trailers</a></li><li><a href="https://www.filmaffinity.com/es/latestreviews.php">Últimas críticas users</a></li><li><a href="https://www.filmaffinity.com/es/category.php?id=latest_reviews">Qué dice la crítica</a></li><li><a href="https://www.filmaffinity.com/es/topics.php">Películas por temas</a></li><li><a href="https://www.filmaffinity.com/es/movie-groups-all.php">Sagas &amp; Franquicias</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Series de TV</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/cat_current_tv.html">Series de actualidad</a></li><li><a href="https://www.filmaffinity.com/es/topgen.php?genres=-DO&amp;chv=1&amp;orderby=avg&amp;movietype=serie%7Conly-serie&amp;country=&amp;fromyear=1874&amp;toyear=2021&amp;ratingcount=3&amp;runtimemin=0&amp;runtimemax=4">Top series</a></li><li><a href="https://www.filmaffinity.com/es/tour.php?idtour=26">Vota Series de TV</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">TOPs</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/topgen.php">Top Filmaffinity</a></li><li><a href="https://www.filmaffinity.com/es/best_tops.php">Lo mejor del TOP</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_th_es.html">Top Estrenos</a></li><li><a href="https://www.filmaffinity.com/es/topcat_new_sa_es.html">Top Estrenos Blu-ray</a></li><li><a href="https://www.filmaffinity.com/es/listsrank.php">Ranking de listas</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Premios | Festivales</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/all_awards.php">Premios y Festivales</a></li><li><a href="https://www.filmaffinity.com/es/oscar_data.php">Todos los Oscar</a></li><li><a href="https://www.filmaffinity.com/es/best_2021.php">Resumen 2021</a></li></ul></div>
# <div class="cat-container">
# <div class="lsmheader">Información</div>
# <ul>
# <li><a href="https://www.filmaffinity.com/es/site-guide.php">Acerca de FA</a></li><li><a href="https://www.filmaffinity.com/es/contact_us.php">Contacto</a></li></ul></div>
# </div>
# </td>
# <td>
# <div id="mt-content-cell">
# <div id="sh-pos-abs">
# <div class="sh-header" title="compartir"><i class="fas fa-share-alt"></i></div>
# </div>
# <style>
#     #hidden-url {position: absolute; left: 65px; top: 2px; display: none; padding: 2px 6px 4px 6px; background: #fdcc1a; margin-top: 5px; width: 485px; border-radius: 5px; animation-duration: .3s; z-index: 100;}
#     #hidden-url input{ font-size: 14px; font-weight: bold; outline: none; border: 1px solid #DDDDDD; border-radius: 5px; padding: 8px 4px; width: 435px; margin-left: 5px; font-family: monospace;}
#     #hidden-url .hide-url {cursor: pointer; font-size: 22px; margin: 0 5px; color: #000; vertical-align: middle;}
#     #copy-clipboard {position: absolute; left: 0px; top: 31px; padding: 2px 6px; background: #fdcc1a; margin-top: 5px; animation-duration: .3s; border-bottom-right-radius: 4px; border-bottom-left-radius: 4px; width: 200px; cursor: pointer; padding-left: 15px;}
# </style>
# <script>
#
#     function hideOnClick( ){
#         $(document).click(function(event) {
#             if(!$(event.target).closest('.hd-sh-wrapper').length && !$(event.target).closest('#hidden-url').length) {
#                 if($('.hd-sh-wrapper').is(":visible")) {
#                     //$('.hidden-share-wrapper').hide();
#                     $('.sh-header').trigger('click');
#                 }
#             }
#         });
#     }
#
#     $(function() {
#         $('.hd-sh-wrapper').bind('animationEnd oAnimationEnd msAnimationEnd mozAnimationEnd webkitAnimationEnd', function(event){
#             if(  $(event.target).hasClass('nkoout') )
#             {
#                 $('.hd-sh-wrapper').hide();
#             }
#
#         });
#
#         $('#sh-pos-abs').toggle( function(){
#                 $('.sh-header').addClass('clicked');
#                 $('.hd-sh-wrapper').removeClass('nkoout').addClass('nkoin').show();
#             }, function(){
#                 $('.hd-sh-wrapper').removeClass('nkoin').addClass('nkoout');
#
#                 $('.main-sh').removeClass('clicked');
#                 if( $('#hidden-url').is(":visible") ) {
#                     $('#copy-to-clip').click();
#                 }
#         });
#
#         //var pathname = 'https://www.filmaffinity.com' + location.pathname + location.search;
#         var pathname = encodeURI('https://www.filmaffinity.com/es/film491812.html');
#         var slideOptions = { direction: 'left' };
#
#         $('#copy-to-clip').toggle(
#             function(){
#                 $('#hidden-url').show();
#
#                     $('#hidden-url').find(':input').val(pathname);
#                     //$('#hidden-url').find(':input').select();
#                     var text = $('#hidden-url').find(':input').text();
#             },
#             function(){
#                     $('#hidden-url').hide();
#         });
#
#         $('#hidden-url').on('click', '#copy-clipboard', function(){
#             $(this).text( $('#copy-clipboard').attr('data-text') );
#             navigator.clipboard.writeText( pathname )
#                 .then(() => {
#                     console.log( pathname );
#             }).catch(err => {
#                     console.error('Could not copy text: ', err);
#             });
#         })
#
#         $('#hidden-url').find('.hide-url').click(function()
#         {
#             $('#copy-to-clip').trigger('click')
#         });
#
#         hideOnClick();
#     });
# </script>
# <div class="hd-sh-main-wrapper">
# <div class="hd-sh-wrapper">
# <a href="#" id="copy-to-clip" title="Copia la URL para compartir">
# <div class="share-icon" id="copy-to-clip-container"><i class="fas fa-link"></i></div>
# </a>
# <a class="fb-sh" href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ffilm491812.html&amp;t=Spider-Man: No Way Home  (2021)" target="_BLANK" title="Comparte en Facebook">
# <div class="share-icon"><i class="fab fa-facebook-f"></i></div>
# </a>
# <a class="tw-sh" href="https://twitter.com/intent/tweet?text=Spider-Man%3A%20No%20Way%20Home%20%20%282021%29 en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ffilm491812.html" target="_BLANK" title="Comparte en Twitter">
# <div class="share-icon"><i class="fab fa-twitter"></i></div>
# </a>
# <a class="wh-sh" href="https://api.whatsapp.com/send?text=Spider-Man%3A%20No%20Way%20Home%20%20%282021%29 en @filmaffinity https%3A%2F%2Fwww.filmaffinity.com%2Fes%2Ffilm491812.html" target="_BLANK" title="Comparte en WhatsApp">
# <div class="share-icon"><i class="fab fa-whatsapp"></i></div>
# </a>
# </div>
# </div>
# <div id="hidden-url">
# <input size="55" type="text"/><i class="fas fa-times-circle hide-url"></i>
# <div data-text="Copiado" id="copy-clipboard">Haz click aquí para copiar la URL</div>
# </div>
# <div itemscope="" itemtype="http://schema.org/Movie">
# <h1 id="main-title">
# <span itemprop="name">Spider-Man: No Way Home </span>
# </h1>
# <script>
# $(document).ready(function(){
#     $("#show-all-pro").click(function(event){
#         $(this).parent('li').css('display', 'none');
#         event.preventDefault();
#         $(".hidden").slideDown('slow');
#     });
#
#     $("#show-all-awards").click(function(event){
#         $(this).parent('div').css('display', 'none');
#         event.preventDefault();
#         $(".hidden-awards").slideDown('slow');
#     });
#
#     $('.z-movie .credits').on('click', '.see-more-credits' ,function(){
#         $(this).closest('div').find('.hidden-credit').css('display', 'inline-block');
#         var $last = $(this).closest('div').find('.nb:last a');
#         if( $last.length == 0 ){
#             var $last = $(this).closest('div').find('.nb:last span');
#         }
#
#         $(this).closest('div').find('.nb:last').html($last[0].outerHTML);
#         $(this).closest('div').find('.t-p').hide();
#
#         //$(this).html("ver menos").addClass('see-less-credits').removeClass('see-more-credits');
#         $(this).remove();
#     })
# /*
#     $('.z-movie .credits').on('click', '.see-less-credits' , function(){
#         $(this).closest('div').find('.hidden-credit').css('display', 'none');
#         $(this).html("Ver todos").addClass('see-more-credits').removeClass('see-less-credits');
#         $(this).closest('div').find('.t-p').show();
#     })
# */
#     $("#cboxOverlay").on('click', function(){
#         return false;
#     });
#
#     $('.show-akas').on('click', function()
#     {
#         var icon = $(this).find('i');
#         if(icon.hasClass('fa-caret-down'))
#         {
#             $('.akas').slideDown();
#             icon.removeClass('fa-caret-down').addClass('fa-caret-up');
#         }
#         else
#         {
#             $('.akas').slideUp();
#             icon.removeClass('fa-caret-up').addClass('fa-caret-down');
#         }
#
#     });
# });
# </script>
# <script>
#             $(document).ready(function(){
#                 new RatingBars($('#rat-disp'), [25,53,100,97,51,17,6,3,2,2]);
#             });
#         </script>
# <div class="z-movie">
# <script>
# $(document).ready(function(){
#     $("#more-categories").click(function(e){
#          e.stopPropagation();
#         $(".hidden-menu").toggle();
#     });
#
#     //para poner el letrerito de novedad
#     //$(".new").append('<div id="tooltip-new">novedad</div>');
# });
#
# $(document).click(function() {
#     $(".hidden-menu").css('display', 'none');
# });
#
# </script>
# <div class="margin-ntabs">
# <div id="movie-categories">
# <a href="https://www.filmaffinity.com/es/cat_new_th_es.html">Cartelera España</a>
# <a href="https://www.filmaffinity.com/es/rdcat.php?id=new_th_es"><strong>17/12/2021</strong></a>
#
#
#                  <span id="more-categories"><i class="fas fa-chevron-down strip-down"></i></span>
# <div class="hidden-menu">
# <ul>
# <li>
# <a href="https://www.filmaffinity.com/es/category.php?id=2021films">100 películas a seguir el 2021</a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/cat_new_th_us.html">Cartelera USA</a>
# <a href="https://www.filmaffinity.com/es/rdcat.php?id=new_th_us"><strong>17/12/2021</strong></a>
# </li>
# <li>
# <a href="https://www.filmaffinity.com/es/cat_new_th_fr.html">Cartelera Francia</a>
# <a href="https://www.filmaffinity.com/es/rdcat.php?id=new_th_fr"><strong>15/12/2021</strong></a>
# </li>
# </ul>
# </div>
# </div>
# <ul class="ntabs">
# <li class="active"><a href="https://www.filmaffinity.com/es/film491812.html">Ficha </a></li>
# <li><a href="https://www.filmaffinity.com/es/reviews/1/491812.html">Críticas <em>[199]</em></a></li>
# <li><a href="https://www.filmaffinity.com/es/evideos.php?movie_id=491812">Tráilers <em>[6]</em></a></li>
# <li><a href="https://www.filmaffinity.com/es/filmimages.php?movie_id=491812">Imágenes <em>[17]</em></a></li>
# <li><a href="https://www.filmaffinity.com/es/movie-showtimes.php?id=491812">Cines <em>[184]</em></a></li>
# </ul>
# </div>
# <div id="right-column">
# <div id="movie-main-image-container">
# <a class="lightbox" data-movie-id="491812" data-t="&lt;p style=font-size:9px;font-family:arial;color:#666666;&gt;El copyright de las imágenes pertenece a sus respectivos autores y/o productoras/distribuidoras.&lt;/p&gt;" href="https://pics.filmaffinity.com/spider_man_no_way_home-642739124-large.jpg" style="display: block;" title="Spider-Man: No Way Home ">
# <img alt="Spider-Man: No Way Home " height="238" itemprop="image" src="https://pics.filmaffinity.com/spider_man_no_way_home-642739124-mmed.jpg" width="160"/> <span class="see-trailer" title="Ver trailer"><i class="fas fa-play-circle"></i></span>
# </a>
# </div>
# <div id="rat-container">
# <div id="rat-avg-count" itemprop="aggregateRating" itemscope="" itemtype="http://schema.org/AggregateRating">
# <div id="movie-rat-image"><span id="stars"><img alt="Votación" src="/imgs/ratings/7.png"/></span></div>
# <div id="rat-avg-container">
# <div content="7.4" id="movie-rat-avg" itemprop="ratingValue">
#                         7,4                    </div>
# <meta content="10" itemprop="bestRating">
# <meta content="1" itemprop="worstRating">
# <meta content="199" itemprop="reviewCount"/>
# <div id="movie-count-rat">
# <span content="16127" itemprop="ratingCount">16.127</span>
# <div id="movie-count-rat-text">votos</div>
# </div>
# <div class="clearfix"></div>
# </meta></meta></div>
# </div>
# <div id="rat-graph">
# <canvas height="81" id="rat-disp" style="padding: 3px; background: #fff; border: 1px solid #CDDCEB" width="120">
#                     Plugin no soportado                </canvas>
# </div>
# <div id="review-container">
# <div id="movie-reviews-box">
#                         199 <a href="https://www.filmaffinity.com/es/reviews/1/491812.html">críticas</a> - <a href="https://www.filmaffinity.com/es/reviews2/1/491812.html">títulos</a>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="rate-movie-box" data-movie-id="491812" data-user-rating="">
# <div class="rate-wrapper">
# <div class="rt-box"><a class="sign-in" href="https://www.filmaffinity.com/es/login.php">Vota esta película</a></div>
# </div>
# </div>
# <div class="add-movie-list-cont">
# <div class="add-text-content">
# <div class="add-movie-list-info add-to-list-button">
# <a href="https://www.filmaffinity.com/es/edtmovielists.php?movie_id=491812">Añadir a listas</a> </div>
# </div>
# <div class="lists-box"></div>
# </div>
# <a href="https://www.filmaffinity.com/es/pro-reviews.php?movie-id=491812">
# <div class="film-right-box pro-reviews-chart">
# <div class="title">Críticas profesionales</div>
# <div class="body">
# <div class="pro-reviews-chart-wrapper">
# <div class="total-abs" title="51 críticas profesionales">
#                     51 <small><i class="fa fa-simple-user-o-fa"></i></small>
# </div>
# <canvas id="myChart" style="position: absolute; left: 10px; width: 70px; height: 70px;"></canvas>
# <div class="legend-wrapper">
# <div class="leg">41<i class="fa fa-simple-user-o-fa"></i> <i class="fas fa-circle pos" style="color: #4CAF50" title="tendencia de la crítica: positiva"></i></div>
# <div class="leg">9<i class="fa fa-simple-user-o-fa"></i> <i class="fas fa-circle neu" style="color: #FFBF00" title="tendencia de la crítica: neutral"></i></div>
# <div class="leg">1<i class="fa fa-simple-user-o-fa"></i> <i class="fas fa-circle neg" style="color: #F44336" title="tendencia de la crítica: negativa"></i></div>
# </div>
# </div>
# </div><!-- body -->
# </div>
# </a>
# <script>
#         var randomScalingFactor = function() {
#             return Math.round(Math.random() * 100);
#         };
#
#     var ctx = document.getElementById('myChart');
#         var config = {
#             type: 'doughnut',
#             data: {
#                 datasets: [{
#                     data: [
#                         320,
#                         72,
#                         8,
#                     ],
#                     backgroundColor: [
#                         '#008000',
#                         '#FFA500',
#                         '#FF0000',
#                     ],
#                     label: 'Dataset 1'
#                 }],
#                 labels: [
#                     'Positivas',
#                     'Neutras',
#                     'Negativas',
#                 ]
#             },
#             options: {
#                 responsive: false,
#                 legend: {
#                     display: false,
#                 },
#                 title: {
#                     display: false,
#                 },
#                 animation: {
#                     animateScale: true,
#                     animateRotate: true
#                 },
#                 cutoutPercentage: 75,
#                 tooltips: {
#                     enabled: false,
#                 },
#             }
#         };
#     var myChart = new Chart(ctx, config);
# </script>
# <div class="film-right-box film-ext-links">
# <div class="title">Links</div>
# <div class="body">
# <div><a href="https://es.wikipedia.org/wiki/Spider-Man:_No_Way_Home" target="_BLANK" title="https://es.wikipedia.org/wiki/Spider-Man:_No_Way_Home"><i class="fab fa-wikipedia-w"></i></a></div>
# </div>
# </div>
# <div class="film-right-box">
# <div class="title" style="position: relative;">
# <a href="https://www.filmaffinity.com/es/movie-relations.php?movie-id=491812" title="Relaciones">
# Tiene 1 relación                    <i class="fas fa-angle-double-right"></i>
# </a>
# </div>
# <div class="body">
# <div class="poster-rels">
# <div class="poster-rel">
# <div class="rel-title">
# <div class="sep sep-0"></div>
# <div class="title">secuela de:</div>
# </div>
# <a href="https://www.filmaffinity.com/es/film978970.html" title="Spider-Man: Lejos de casa "><img alt="Spider-Man: Lejos de casa " height="149" src="https://pics.filmaffinity.com/spider_man_far_from_home-339542528-msmall.jpg" width="100"/></a>
# <div class="movie-title"><a href="https://www.filmaffinity.com/es/film978970.html">Spider-Man: Lejos de casa </a></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="left-column">
# <dl class="movie-info">
# <dt>Título original</dt>
# <dd>
#                 Spider-Man: No Way Home             </dd>
# <dt>Año</dt>
# <dd itemprop="datePublished">2021</dd>
# <dt>Duración</dt>
# <dd itemprop="duration">148 min.</dd>
# <dt>País</dt>
# <dd><span id="country-img"><img alt="Estados Unidos" class="nflag" src="/imgs/countries2/US.png"/></span> Estados Unidos</dd>
# <dt>Dirección</dt>
# <dd class="directors">
# <div class="credits"><span class="nb" itemprop="director" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=director&amp;sn&amp;stext=Jon%20Watts" itemprop="url" title="Jon Watts"><span itemprop="name">Jon Watts</span></a></span></div> </dd>
# <dt>Guion</dt>
# <dd><div class="credits"><span class="nb"><span>Chris McKenna</span>,</span> <span class="nb"><span>Erik Sommers</span>. </span><i> Cómic:</i> <span class="nb"><span>Steve Ditko</span>,</span> <span class="nb"><span>Stan Lee</span></span></div></dd>
# <dt>Música</dt>
# <dd><div class="credits"><span class="nb"><span>Michael Giacchino</span></span></div></dd>
# <dt>Fotografía</dt>
# <dd><div class="credits"><span class="nb"><span>Mauro Fiore</span></span></div></dd>
# <dt>Reparto</dt>
# <dd class="card-cast">
# <div class="credits"><span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Tom%20Holland" itemprop="url" title="Tom Holland"><span itemprop="name">Tom Holland</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Zendaya" itemprop="url" title="Zendaya"><span itemprop="name">Zendaya</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Benedict%20Cumberbatch" itemprop="url" title="Benedict Cumberbatch"><span itemprop="name">Benedict Cumberbatch</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Alfred%20Molina" itemprop="url" title="Alfred Molina"><span itemprop="name">Alfred Molina</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Tobey%20Maguire" itemprop="url" title="Tobey Maguire"><span itemprop="name">Tobey Maguire</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Andrew%20Garfield" itemprop="url" title="Andrew Garfield"><span itemprop="name">Andrew Garfield</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Willem%20Dafoe" itemprop="url" title="Willem Dafoe"><span itemprop="name">Willem Dafoe</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Marisa%20Tomei" itemprop="url" title="Marisa Tomei"><span itemprop="name">Marisa Tomei</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Jacob%20Batalon" itemprop="url" title="Jacob Batalon"><span itemprop="name">Jacob Batalon</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Jon%20Favreau" itemprop="url" title="Jon Favreau"><span itemprop="name">Jon Favreau</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Angourie%20Rice" itemprop="url" title="Angourie Rice"><span itemprop="name">Angourie Rice</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Jamie%20Foxx" itemprop="url" title="Jamie Foxx"><span itemprop="name">Jamie Foxx</span></a>,</span> <span class="nb" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=J.K.%20Simmons" itemprop="url" title="J.K. Simmons"><span itemprop="name">J.K. Simmons</span></a>,</span> <span class="nb hidden-credit" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast&amp;sn&amp;stext=Thomas%20Haden%20Church" itemprop="url" title="Thomas Haden Church"><span itemprop="name">Thomas Haden Church</span></a>,</span> <span class="nb hidden-credit" itemprop="actor" itemscope="" itemtype="http://schema.org/Person"><a href="https://www.filmaffinity.com/es/search.php?stype=cast& ...
# <style>.card-producer .credits {display: inline;}</style>
# <dt>Productora</dt>
# <dd class="card-producer">
# <div class="credits"><span class="nb"><span>Pascal Pictures</span>,</span> <span class="nb"><span>Marvel Studios</span>,</span> <span class="nb"><span>Columbia Pictures</span>. </span><i> Distribuidora:</i> <span class="nb"><span>Columbia Pictures</span>,</span> <span class="nb"><span>Sony Pictures Entertainment (SPE)</span></span></div> </dd>
# <dt>Género</dt>
# <dd class="card-genres">
# <span itemprop="genre"><a href="https://www.filmaffinity.com/es/moviegenre.php?genre=FAN&amp;attr=rat_count&amp;nodoc">Fantástico</a></span>.                 <span itemprop="genre"><a href="https://www.filmaffinity.com/es/moviegenre.php?genre=AC&amp;attr=rat_count&amp;nodoc">Acción</a></span>.                 <span itemprop="genre"><a href="https://www.filmaffinity.com/es/moviegenre.php?genre=C-F&amp;attr=rat_count&amp;nodoc">Ciencia ficción</a></span> |                 <a href="https://www.filmaffinity.com/es/movietopic.php?topic=462123&amp;attr=rat_count&amp;nodoc">Superhéroes</a>.                 <a href="https://www.filmaffinity.com/es/movietopic.php?topic=638971&amp;attr=rat_count&amp;nodoc">Secuela</a>.                 <a href="https://www.filmaffinity.com/es/movietopic.php?topic=725819&amp;attr=rat_count&amp;nodoc">Cómic</a>.                 <a href="https://www.filmaffinity.com/es/movietopic.php?topic=307488&amp;attr=rat_count&amp;nodoc">Marvel Comics</a>.                 <a href="https://www.filmaffinity.com/es/movietopic.php?topic=565134&amp;attr=rat_count&amp;nodoc">MCU</a> </dd>
# <dt>Grupos</dt>
# <dd style="position: relative;">
# <span><a href="https://www.filmaffinity.com/es/movie-group.php?group-id=18" title="Marvel Cinematic Universe (MCU)">Marvel Cinematic Universe (MCU)</a></span>
#  |                     <span><a href="https://www.filmaffinity.com/es/movie-group.php?group-id=74" title="Spider-Man">Spider-Man</a></span>
#  |                     <span><a href="https://www.filmaffinity.com/es/movie-group.php?group-id=1140" title="Doctor Extraño">Doctor Extraño</a></span>
#  |                     <span><a href="https://www.filmaffinity.com/es/movie-group.php?group-id=1791" title="Marvel: Fase 4 (Películas y Series)">Marvel: Fase 4 (Películas y Series)</a></span>
# </dd>
# <dt>Sinopsis</dt>
# <dd class="" itemprop="description">Por primera vez en la historia cinematográfica de Spider-Man, nuestro héroe, vecino y amigo es desenmascarado, y por tanto, ya no es capaz de separar su vida normal de los enormes riesgos que conlleva ser un superhéroe. Cuando pide ayuda al Doctor Strange, los riesgos pasan a ser aún más peligrosos, obligándole a descubrir lo que realmente significa ser él. Secuela de 'Spider-Man: Far From Home'. </dd>
# </dl>
# <dl class="margin-top movie-info">
# <dt>Posición en rankings FA</dt>
# <dd class="no-padding" id="movie-rankings-pos">
# <ul>
# <li><strong>1</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_2021movies">Las mejores películas de ficción de 2021 (no animadas)</a></li>
# <li><strong>2</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fa_2021_movies">Las mejores películas de 2021</a></li>
# <li><strong>2</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_mcu">Ranking del Marvel Cinematic Universe (MCU), de mejor a peor</a></li>
# <li style="display:none"><strong>3</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_marvel">Mejores películas basadas en cómics de Marvel</a></li>
# <li style="display:none"><strong>5</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_superheroes">Mejores películas de superhéroes</a></li>
# <li style="display:none"><strong>13</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_movies_comic">Mejores películas basadas en cómics</a></li>
# <li style="display:none"><strong>30</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_sequels">Mejores secuelas de la historia del cine</a></li>
# <li style="display:none"><strong>39</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_scifi">Mejores películas de ciencia-ficción</a></li>
# <li style="display:none"><strong>41</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_action">Mejores películas de acción</a></li>
# <li style="display:none"><strong>65</strong> <a href="https://www.filmaffinity.com/es/ranking.php?rn=ranking_fantasy">Mejores películas de fantasía</a></li>
# </ul>
# <div class="show-all"><a href="https://www.filmaffinity.com/es/movie-rankings.php?movie-id=491812#rankings">Mostrar los 10 rankings <i class="fas fa-chevron-right"></i></a></div>
# </dd>
# </dl>
# <dl class="margin-top movie-info">
# <dt>Premios</dt>
# <dd class="award">
# <div class="margin-bottom"><a href="https://www.filmaffinity.com/es/awards.php?award_id=academy_awards&amp;year=2022">2021</a>: Premios Oscar: Nominada a mejores efectos visuales</div>
# </dd>
# </dl>
# <dl class="margin-top movie-info">
# <dt>Críticas</dt>
# <dd>
# <ul id="pro-reviews">
# <li>
# <div class="pro-review" itemprop="review" itemscope="" itemtype="http://schema.org/Review">
# <a href="https
# </div>
# </div>
# </dd>
# </dl>
# <dl class="margin-top movie-info">
# <dt style="padding-bottom: 50px;">Votaciones de almas gemelas</dt>
# <dd style="padding-bottom: 50px;">
# <div class="margin-bottom" id="sm-m-rat">
# <a href="https://www.filmaffinity.com/es/register.php">Regístrate</a> y podrás acceder a recomendaciones personalizadas según tus gustos de cine            </div>
# </dd>
# <dt>Votaciones de tus amigos</dt>
# <dd>
# <div class="margin-bottom" id="fr-m-rat">
# <div><a href="https://www.filmaffinity.com/es/register.php">Regístrate</a> y podrás acceder a todas las votaciones de tus amigos, familiares, etc.</div>
# </div>
# </dd>
# </dl>
# <script>
#         $(function(){
#             $('#list-top-rank li').each(function(indx, value){
#                 $(value).attr('title', $(value).find('em').text().match(/\d+/) + ' apariciones en esta lista');
#             });
#         });
#     </script>
# <dl class="margin-top movie-info">
# <dt>Posición rankings listas</dt>
# <dd class="no-padding" id="list-top-rank">
# <ul>
# <li><strong>5</strong> <a href="https://www.filmaffinity.com/es/listtopmovies.php?list_id=128">Mis películas favoritas del 2021</a> <em>(148)</em></li>
# <li><strong>88</strong> <a href="https://www.filmaffinity.com/es/listtopmovies.php?list_id=400">Las mejores películas que he visto últimamente en el cine</a> <em>(22)</em></li>
# <li><strong>98</strong> <a href="https://www.filmaffinity.com/es/listtopmovies.php?list_id=200">Próximos estrenos: éstas no me las pierdo</a> <em>(187)</em></li>
# <li><strong>100</strong> <a href="https://www.filmaffinity.com/es/listtopmovies.php?list_id=505">Mis adaptaciones de cómics preferidas</a> <em>(33)</em></li>
# </ul>
# </dd>
# </dl>
# <div class="movie-disclaimer" style="margin-top: 60px; ">
# <p>Si alguna sinopsis cuenta demasiados detalles del argumento, si ves algún error que desees corregir o para completar datos de la ficha o añadir fechas de estreno en tu país- puedes mandarnos un <a href="https://www.filmaffinity.com/es/imsendmsg.php?to=985462">mensaje interno en la página</a>. Si no estás registrado/a puedes contactarnos vía Twitter, IG, FB o por email a info -arroba- filmaffinity -punto- com.
# <p>Los derechos de propiedad intelectual de las críticas corresponden a los correspondientes críticos y/o medios de comunicación de los que han sido extraídos. Filmaffinity no tiene relación alguna con el productor, productora o distribuidor/a de la película. El copyright del poster, carátula, fotogramas, fotografías e imágenes de cada DVD, VOD, Blu-ray, tráiler y banda sonora original (BSO) pertenecen a las correspondientes productoras y/o distribuidoras.</p>
# </p></div>
# </div>
# </div>
# </div>
# </div>
# <div style="padding-top: 50px; clear: both;"><div>
# </div></div></td>
# </tr>
# </table>
# </div>
# <div id="bpanel">
# <div style="text-align:center; padding: 10px">
# <a href="https://www.filmaffinity.com/es/faq.php">Preguntas más frecuentes</a>
#     | <a href="https://www.filmaffinity.com/es/private.php">Política de privacidad / condiciones de uso</a>
#     | <a href="#" id="privacy-config-2">Configuración de privacidad</a>
#     | <a href="https://m.filmaffinity.com/es/movie.php?id=491812"><strong>Ir a Versión MÓVIL</strong></a>
# </div>
# <div style="text-align:center; padding: 10px 2px">
# <span class="subtext">© 2002-2022 Filmaffinity - Movieaffinity | Filmaffinity es una página de recomendación de películas y series, y es un medio totalmente independiente cuya principal prioridad es la privacidad y seguridad de los datos de sus usuarios.<br/>All Rights Reserved - Todos los derechos reservados</span>
# </div>
# </div>
# </body>
# </html>

# %%
# Titulo

soup.find("dd").text

# soup.find("dd").text.strip()
# Out:
# '\n                Spider-Man: No Way Home             '

# %%
# Año

dict_bs4 = {"itemprop" : "datePublished"}

soup.find("dd", attrs = dict_bs4).text
# Out:
# '2021'

# %%
# Duracion

dict_bs4 = {"itemprop" : "duration"}

soup.find("dd", attrs = dict_bs4).text
# Out:
# '148 min.'

# %%
# Pais

dict_bs4 = {"id" : "country-img"}

soup.find("span", attrs = dict_bs4).find("img")["alt"]
# Out:
# 'Estados Unidos'

# %%
# Guion (Aqui es más complicado por como esta estructurada la página)

soup.find_all("div", class_ = "credits")[1].text
# Out:
# 'Chris McKenna, Erik Sommers.  Cómic: Steve Ditko, Stan Lee'

# %%
# Musica (Aqui es más complicado por como esta estructurada la página)

soup.find_all("div", class_ = "credits")[2].text
# Out:
# 'Michael Giacchino'

# %%
# Fotografia (Aqui es más complicado por como esta estructurada la página)

soup.find_all("div", class_ = "credits")[3].text
# Out:
# 'Mauro Fiore'

# %%
# Reparto (Aqui es más complicado por como esta estructurada la página)

soup.find_all("div", class_ = "credits")[4].text
# Out:
# 'Tom Holland, Zendaya, Benedict Cumberbatch, Alfred Molina, Tobey Maguire, Andrew Garfield, Willem Dafoe, Marisa Tomei, Jacob Batalon, Jon Favreau, Angourie Rice, Jamie Foxx, J.K. Simmons, Thomas Haden Church, Rhys Ifans, Harry Holland, Christopher Cocke, J.B. Smoove, Benedict Wong, Hannibal Buress, Martin Starr, Tony Revolori.   Cameo: Charlie Cox, Tom Hardyver 11 más'

# %%
# Productora 

" ".join([t.text for t in soup.find("dd", class_ = "card-producer").find_all("span", class_ = "nb")])
# Out:
# 'Pascal Pictures, Marvel Studios, Columbia Pictures.  Columbia Pictures, Sony Pictures Entertainment (SPE)'

# %%
# Géneros

" ".join(soup.find("dd", class_ = "card-genres").text.split())
# Out:
# 'Fantástico. Acción. Ciencia ficción | Superhéroes. Secuela. Cómic. Marvel Comics. MCU'

# %%
# Grupos

" ".join(soup.find("dd", attrs = {"style" : "position: relative;"}).text.split())
# Out:
# 'Marvel Cinematic Universe (MCU) | Spider-Man | Doctor Extraño | Marvel: Fase 4 (Películas y Series)'

# %%
# Sinopsis

soup.find("dd", attrs = {"itemprop" : "description"}).text
# Out:
# "Por primera vez en la historia cinematográfica de Spider-Man, nuestro héroe, vecino y amigo es desenmascarado, y por tanto, ya no es capaz de separar su vida normal de los enormes riesgos que conlleva ser un superhéroe. Cuando pide ayuda al Doctor Strange, los riesgos pasan a ser aún más peligrosos, obligándole a descubrir lo que realmente significa ser él. Secuela de 'Spider-Man: Far From Home'. "

# %%
from time import sleep

# %%
# Crear un DataFrame

titulos = list()
años = list()
duraciones = list()
paises = list()
direcciones = list()
guiones = list()
musicas = list()
fotografias = list()
repartos = list()
productoras = list()
generos = list()
grupos = list()
sinopsises = list()

for url in df["urls"]:
    
    print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")

    titulo = soup.find("dd").text.strip()
    año = soup.find("dd", attrs = {"itemprop" : "datePublished"}).text
    duracion = soup.find("dd", attrs = {"itemprop" : "duration"}).text
    pais = soup.find("span", attrs = {"id" : "country-img"}).find("img")["alt"]
    direccion = soup.find_all("div", class_ = "credits")[1].text
    guion = soup.find_all("div", class_ = "credits")[2].text
    musica = soup.find_all("div", class_ = "credits")[3].text
    fotografia = soup.find_all("div", class_ = "credits")[3].text
    reparto = soup.find_all("div", class_ = "credits")[4].text
    productora = " ".join([t.text for t in soup.find("dd", class_ = "card-producer").find_all("span", class_ = "nb")])
    genero = " ".join(soup.find("dd", class_ = "card-genres").text.split())
    grupo = " ".join(soup.find("dd", attrs = {"style" : "position: relative;"}).text.split())
    sinopsis = soup.find("dd", attrs = {"itemprop" : "description"}).text
    
    titulos.append(titulo)
    años.append(año)
    duraciones.append(duracion)
    paises.append(pais)
    direcciones.append(direccion)
    guiones.append(guion)
    musicas.append(musica)
    fotografias.append(fotografia)
    repartos.append(reparto)
    productoras.append(productora)
    generos.append(genero)
    grupos.append(grupo)
    sinopsises.append(sinopsis)
    
    sleep(3)
# Out:
# https://www.filmaffinity.com/es/film491812.html
# https://www.filmaffinity.com/es/film281888.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11316/448743291.py in <module>
#      33     productora = " ".join([t.text for t in soup.find("dd", class_ = "card-producer").find_all("span", class_ = "nb")])
#      34     genero = " ".join(soup.find("dd", class_ = "card-genres").text.split())
# ---> 35     grupo = " ".join(soup.find("dd", attrs = {"style" : "position: relative;"}).text.split())
#      36     sinopsis = soup.find("dd", attrs = {"itemprop" : "description"}).text
#      37
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# Muchas veces sucede que no todas las páginas tienen la misma información, por lo que tenemos que asegurarnos de que si no existe un dato lo sustituimos con un np.nan. Por eso podemos usar:
# ```python
# try:
#
# except:
# ```

# %%
# Crear un DataFrame

titulos = list()
años = list()
duraciones = list()
paises = list()
direcciones = list()
guiones = list()
musicas = list()
fotografias = list()
repartos = list()
productoras = list()
generos = list()
grupos = list()
sinopsises = list()

for url in df["urls"]:
    
    print(url)
    
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    
#### Titulo #######################################################################################################   

    try:
        titulo = soup.find("dd").text.strip()
        
    except:
        titulo = np.nan
        
#### Año ##########################################################################################################   

    try:
        año = soup.find("dd", attrs = {"itemprop" : "datePublished"}).text
        
    except:
        año = np.nan

#### Duracion #####################################################################################################

    try:
        duracion = soup.find("dd", attrs = {"itemprop" : "duration"}).text
        
    except:
        duracion = np.nan

#### Pais #########################################################################################################

    try:
        pais = soup.find("span", attrs = {"id" : "country-img"}).find("img")["alt"]
        
    except:
        pais = np.nan

#### Direccion ####################################################################################################

    try:
        direccion = soup.find_all("div", class_ = "credits")[1].text
        
    except:
        direccion = np.nan

#### Guion ########################################################################################################

    try:
        guion = soup.find_all("div", class_ = "credits")[2].text
        
    except:
        guion = np.nan

#### Musica #######################################################################################################

    try:
        musica = soup.find_all("div", class_ = "credits")[3].text
        
    except:
        musica = np.nan

#### Fotografia ###################################################################################################

    try:
        fotografia = soup.find_all("div", class_ = "credits")[3].text
        
    except:
        fotografia = np.nan

#### Reparto ######################################################################################################

    try:
        reparto = soup.find_all("div", class_ = "credits")[4].text
        
    except:
        reparto = np.nan

#### Productora ###################################################################################################

    try:
        productora = " ".join([t.text for t in soup.find("dd", class_ = "card-producer").find_all("span", class_ = "nb")])
        
    except:
        productora = np.nan

#### Genero #######################################################################################################

    try:
        genero = " ".join(soup.find("dd", class_ = "card-genres").text.split())
        
    except:
        genero = np.nan

#### Grupo ########################################################################################################

    try:
        grupo = " ".join(soup.find("dd", attrs = {"style" : "position: relative;"}).text.split())
        
    except:
        grupo = np.nan

#### Sinopsis #####################################################################################################

    try:
        sinopsis = soup.find("dd", attrs = {"itemprop" : "description"}).text
        
    except:
        sinopsis = np.nan
        
##################################################################################################################

    # appends
    
    titulos.append(titulo)
    años.append(año)
    duraciones.append(duracion)
    paises.append(pais)
    direcciones.append(direccion)
    guiones.append(guion)
    musicas.append(musica)
    fotografias.append(fotografia)
    repartos.append(reparto)
    productoras.append(productora)
    generos.append(genero)
    grupos.append(grupo)
    sinopsises.append(sinopsis)
    
    sleep(3)
# Out:
# https://www.filmaffinity.com/es/film491812.html
# https://www.filmaffinity.com/es/film281888.html
# https://www.filmaffinity.com/es/film925403.html
# https://www.filmaffinity.com/es/film776481.html
# https://www.filmaffinity.com/es/film571166.html
# https://www.filmaffinity.com/es/film375190.html
# https://www.filmaffinity.com/es/film658785.html
# https://www.filmaffinity.com/es/film454387.html
# https://www.filmaffinity.com/es/film555900.html
# https://www.filmaffinity.com/es/film465767.html
# https://www.filmaffinity.com/es/film407458.html
# https://www.filmaffinity.com/es/film963718.html
# https://www.filmaffinity.com/es/film822006.html
# https://www.filmaffinity.com/es/film691628.html
# https://www.filmaffinity.com/es/film767738.html
# https://www.filmaffinity.com/es/film580527.html
# https://www.filmaffinity.com/es/film115715.html
# https://www.filmaffinity.com/es/film975136.html
# https://www.filmaffinity.com/es/film468660.html
# https://www.filmaffinity.com/es/film880572.html
# https://www.filmaffinity.com/es/film405972.html
# https://www.filmaffinity.com/es/film596523.html
# https://www.filmaffinity.com/es/film184929.html
# https://www.filmaffinity.com/es/film315057.html
# https://www.filmaffinity.com/es/film577324.html
# https://www.filmaffinity.com/es/film738775.html
# https://www.filmaffinity.com/es/film622126.html
# https://www.filmaffinity.com/es/film799681.html
# https://www.filmaffinity.com/es/film757813.html
# https://www.filmaffinity.com/es/film198721.html
# https://www.filmaffinity.com/es/film931173.html
# https://www.filmaffinity.com/es/film453220.html
# https://www.filmaffinity.com/es/film948651.html
# https://www.filmaffinity.com/es/film242779.html
# https://www.filmaffinity.com/es/film748908.html
# https://www.filmaffinity.com/es/film158517.html
# https://www.filmaffinity.com/es/film112313.html
# https://www.filmaffinity.com/es/film215095.html
# https://www.filmaffinity.com/es/film889123.html
# https://www.filmaffinity.com/es/film967255.html

# %%
df_peliculas = pd.DataFrame()

df_peliculas["titulo"] = titulos
df_peliculas["año"] = años
df_peliculas["duracion"] = duraciones
df_peliculas["pais"] = paises
